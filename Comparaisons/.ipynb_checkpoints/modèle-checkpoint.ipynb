# %%
import json
import glob
import re
import codecs

print(glob.glob("*"))

def ouvrir_fichier(path):
    f = codecs.open(path, encoding="utf-8")
    chaine = f.read()
    f.close()
    return chaine

def decouper_mots(texte):
    mots = re.findall("[a-zA-ZÀ-ÿ][a-zA-ZÀ-ÿ-]*", texte)
    return mots

def write_json(path, contenu):
    w = codecs.open(path, "w", encoding="utf-8")
    w.write(json.dumps(contenu, indent = 2, ensure_ascii=False))
    w.close()
    
def ouvrir_json(path):
    f = codecs.open(path, encoding="utf-8")
    toto = json.load(f)
    f.close()
    return toto
# Out:
# ['notes.odt', 'Deuxieme comparaison manuelle_aijwikiner.ods', 'anno_unification_spacy', 'annoMan_unificationSpacy', 'comparaisonSpaCy_mano-Copy1.ipynb', 'anno_unification_CasEN', 'anno_unification_mano', 'Doc pour Kappa.ods', 'comparaisonCasEN_mano.ipynb', 'Première comparaison manuelle_wikinews.ods']

# %%
folder1 = "anno_unification_CasEN/"
folder2 = "anno_unification_mano/"

# %%
liste_fic = ["APIL", "Wikinews", "Sequoia", "aijwikiner", "GSD", "spoken", "pg6470"]

# %%
ext1 = "_CasEN.json"
ext2 = ".json"

# %% [markdown]
# # Comparaison des deux corpus dans leur entièreté

# %% [markdown]
# ## Exactitude totale

# %% [markdown]
# ### Visualisation

# %%
#on créé un dico des annotations CasEN
dicoCasEN = {}
for i in liste_fic:
    path_fic = folder1+i+ext1
    fic = ouvrir_json(path_fic)
    for j in fic:
        dicoCasEN[j.strip()]=(fic[j]).strip()

# %%
print(dicoCasEN)
# Out:
# {'Pays': 'ORG', 'Cyclo Club Othéen': 'ORG', '2ème jour': 'AMOUNT', '9 h': 'AMOUNT', 'Une seconde': 'AMOUNT', '5 €': 'AMOUNT', '3 €': 'AMOUNT', '14 h': 'AMOUNT', '150 €': 'AMOUNT', 'Une soirée': 'AMOUNT', '355 €': 'AMOUNT', '15 €': 'AMOUNT', '23 juillet': 'TIME', 'Octobre 2011': 'TIME', '15 septembre': 'TIME', '0 et 11 décembre': 'TIME', 'de Noël': 'TIME', '16 juillet': 'TIME', '23 juin au 7 juillet': 'TIME', '26 août': 'TIME', 'Juillet 2011': 'TIME', '4 septembre': 'TIME', 'chaque année': 'TIME', '24 août': 'TIME', '8 septembre': 'TIME', 'auteurs': 'FUNC', 'peintre': 'FUNC', 'Cabaret': 'ORG', 'école primaire': 'ORG', 'Café': 'ORG', 'Musée Colette': 'LOC', 'Château de Guédelon': 'LOC', 'Halle Circulaire': 'LOC', "Villa de l'Extra": 'LOC', 'France': 'LOC', 'Russie': 'LOC', 'Aube': 'LOC', 'Musée du Cidre': 'LOC', 'église': 'LOC', 'MAROLLES-SOUS-LIGNIERES': 'LOC', 'Matthieu Normand': 'PER', 'Nicolas Collinet': 'PER', 'Paul Breisch': 'PER', 'Sylvie Vernageau': 'PER', 'Jean': 'PER', 'Philippe Borecek': 'PER', 'Ivan Netchiporko': 'PER', 'null': 'PER', 'Renoir': 'PER', 'Jean Musy': 'PER', 'Fête du Cochon': 'EVENT', 'Journées du Patrimoine': 'EVENT', 'de 10 h à 18 h': 'TIME', 'entre 12 h et 14 h': 'TIME', 'à 20 h 30': 'TIME', 'à 17 h': 'TIME', 'à 19 h': 'TIME', 'à 18 h': 'TIME', 'à partir de 7 h 30': 'TIME', 'NASA': 'ORG', 'Bolloré': 'ORG', 'LVMH': 'ORG', 'Front National': 'ORG', '5S': 'AMOUNT', '26 ans': 'AMOUNT', '22 ans': 'AMOUNT', '9 mars 2018': 'TIME', 'le 2 novembre 2017': 'TIME', 'le 5 décembre': 'TIME', 'En 1952': 'TIME', 'La semaine dernière': 'TIME', '10 mars 2018': 'TIME', 'avril': 'TIME', '4 mars': 'TIME', '14 mars 2018': 'TIME', 'du 3 mars': 'TIME', '3 mars 2018': 'TIME', 'le 20 mars 2018': 'TIME', 'Le vendredi 2 mars 2018': 'TIME', 'à': 'TIME', 'En 1998': 'TIME', "aujourd'hui": 'TIME', '11 mars 2018': 'TIME', 'le mois précédent': 'TIME', '8 mars 2018': 'TIME', 'juges': 'FUNC', 'chefs': 'FUNC', 'CRS': 'FUNC', 'conducteur': 'FUNC', 'foreuse': 'FUNC', 'patineurs': 'FUNC', 'justice': 'ORG', 'laboratoires': 'ORG', 'armées': 'ORG', 'Terre': 'LOC', 'océan': 'LOC', 'surface': 'LOC', 'Pacifique': 'LOC', 'Belgique': 'LOC', 'Royaume-Uni': 'LOC', 'Égypte': 'LOC', 'Cameroun': 'LOC', 'Nigéria': 'LOC', 'Fukushima': 'LOC', 'Japon': 'LOC', 'SoHO': 'LOC', 'Carcassonne': 'LOC', 'États-Unis': 'LOC', 'Californie': 'LOC', 'Suisse': 'LOC', 'Ouagadougou': 'LOC', 'capitale du': 'LOC', 'Espagne': 'LOC', 'James Webb': 'PER', 'Saturne': 'PER', 'Donald Hadley': 'PER', 'Louis Vuitton': 'PER', 'Quelques mois': 'AMOUNT', 'Sept ans': 'AMOUNT', 'jeux': 'EVENT', 'mondial': 'EVENT', 'Jeux': 'EVENT', 'Jeux olympiques': 'EVENT', 'Dans la matinée': 'TIME', 'Budget': 'ORG', 'Conseil': 'ORG', 'un livre': 'AMOUNT', '2 semaines': 'AMOUNT', '18 ans': 'AMOUNT', 'à partir de 1950': 'TIME', 'Le 17 mai 2004': 'TIME', 'en 1962': 'TIME', 'en 1933': 'TIME', 'en 1994': 'TIME', 'le jour': 'TIME', 'dès septembre 2004': 'TIME', '20 janvier 1994': 'TIME', "Aujourd'hui": 'TIME', 'pour cette nouvelle année': 'TIME', '28 mai 2004': 'TIME', 'le 2 octobre 2006': 'TIME', "dès le mois d' avril 1915": 'TIME', 'délégués': 'FUNC', 'ancien ministre socialiste': 'FUNC', 'procureur': 'FUNC', 'auteur': 'FUNC', 'Banque': 'ORG', 'entreprise': 'ORG', 'Parlement': 'ORG', 'forêt': 'LOC', 'Meuse': 'LOC', 'Afrique': 'LOC', 'Taïwan': 'LOC', 'Chine': 'LOC', 'Créteil': 'LOC', 'ville de': 'LOC', 'USA': 'LOC', 'UE': 'LOC', 'Europe': 'LOC', 'Francis Poullain': 'PER', 'François Mitterrand': 'PER', 'René Bousquet': 'PER', 'Michel Charasse': 'PER', 'Blanche Maupas': 'PER', 'Nicolas Sarkozy': 'PER', 'Charasse': 'PER', 'Andrew Wang': 'PER', 'Théophile Maupas': 'PER', 'Stanley Kubrick': 'PER', 'plusieurs décennies': 'AMOUNT', 'The Normal': 'ORG', 'Metallica': 'ORG', 'Object Management Group': 'ORG', 'United Service Organizations': 'ORG', "Royaume d'": 'ORG', 'premiers livres': 'AMOUNT', 'premières années': 'AMOUNT', 'dix-sept kilomètres': 'AMOUNT', 'deux cent quatre-vingt huit kilomètres': 'AMOUNT', 'quarante ...

# %%
dicoMano = {}
for i in liste_fic:
    path_fic2 = folder2+i+ext2
    fic2 = ouvrir_json(path_fic2)
    for j in fic2:
        dicoMano[j.strip()]=(fic2[j]).strip()

# %%
print(dicoMano)
# Out:
# {'ERVY-LE-CHATEL': 'LOC', '2ème jour du Marché du Livre': 'TIME', 'Marché du Livre': 'EVENT', 'de 10 h à 18 h': 'TIME', 'entre 12 h et 14 h': 'TIME', 'Ervy-le-Châtel': 'LOC', '03 25 76 88 78': 'LOC', '23 juillet': 'TIME', 'LIGNIERES': 'LOC', '5 sauvageonnes comestibles': 'AMOUNT', 'Les Ombelles': 'ORG', '03 25 43 92 26': 'LOC', 'www.lesombelles.com': 'LOC', 'Octobre 2011': 'TIME', '15 septembre': 'TIME', 'AIX-EN-OTHE': 'LOC', 'Musée Colette': 'LOC', 'Château de Guédelon': 'LOC', "Club des Anciens et de amis d'Aix": 'ORG', '06 75 15 06 14': 'LOC', '10 et 11 décembre': 'TIME', 'BOUILLY': 'LOC', 'Marché de Noël': 'EVENT', 'foyer familial': 'LOC', 'Comité des fêtes': 'ORG', 'Récital de Piano 4 mains': 'EVENT', 'Matthieu Normand': 'PER', 'Nicolas Collinet': 'PER', 'Halle Circulaire': 'LOC', 'à 20 h 30': 'TIME', "Villa de l'Extra": 'ORG', '03 25 43 22 10': 'LOC', '06 79 07 79 25': 'LOC', 'http://villa-de-l-extra.skyrock.com/': 'LOC', '16 juillet': 'TIME', 'BERULLE': 'LOC', 'de 9 h 30 à 18 h': 'TIME', 'Bérulle': 'LOC', '5 €': 'AMOUNT', '3 €': 'AMOUNT', '03 25 70 03 05': 'LOC', 'Téléthon': 'EVENT', 'CCAS': 'ORG', 'CHAOURCE': 'LOC', "Concert d'orgue": 'EVENT', 'église': 'LOC', 'Paul Breisch': 'PER', 'cathédrale de Luxembourg': 'LOC', 'Concert': 'EVENT', 'à 17 h': 'TIME', '23 juin au 7 juillet': 'TIME', 'Festival en Othe': 'EVENT', 'www.festivalenothe.org': 'LOC', 'VAUCHASSIS': 'LOC', '41ème fête du cidre': 'EVENT', 'Du 9 au 11 septembre': 'TIME', 'Sylvie Vernageau': 'PER', 'de 9 h 30 à 12 h 30': 'TIME', 'de 14 h 30 à 18 h': 'TIME', '150 €': 'AMOUNT', '03 25 42 10 46': 'LOC', '06 82 96 92 24': 'LOC', 'MARAYE-EN-OTHE': 'LOC', 'Feux de la Saint-Jean': 'EVENT', 'lavoir des boulins': 'LOC', 'à 19 h': 'TIME', 'Maraye Pour Tous': 'ORG', '03 25 80 75 69': 'LOC', 'RACINES': 'LOC', 'Soirée « Entre France et Russie »': 'EVENT', 'France': 'LOC', 'Russie': 'LOC', '20 h 30': 'TIME', 'Philippe Borecek': 'PER', 'Ivan Netchiporko': 'PER', 'ESTISSAC': 'LOC', 'Fête du Cochon': 'EVENT', 'place Caroline': 'LOC', '26 août': 'TIME', 'PALIS': 'LOC', 'la Boule Palisienne': 'ORG', '06 01 71 82 17': 'LOC', 'Fête du tilleul centenaire': 'EVENT', 'EAUX-PUISEAUX': 'LOC', 'Aube': 'LOC', 'Akadêmia': 'ORG', 'Musée du Cidre': 'LOC', '22 rue Largentier': 'LOC', 'rue Largentier': 'LOC', '19 h': 'TIME', '03 26 55 71 80': 'LOC', 'www.akademia.fr': 'LOC', 'Juillet 2011': 'TIME', 'ESSOYES': 'LOC', 'M. Monnet Pierre': 'PER', 'peintre': 'FUNC', "Pays d'Armance": 'LOC', "Au fil de l'Ours, dans les pas de Renoir": 'EVENT', 'Renoir': 'PER', '2 rue du four': 'LOC', 'rue du four': 'LOC', 'Journées du Patrimoine': 'EVENT', 'église Saint Laurent': 'LOC', 'Commission de la Culture': 'ORG', 'MAROLLES-SOUS-LIGNIERES': 'LOC', 'salle des fêtes': 'LOC', 'comité des fêtes': 'ORG', '03 25 76 01 38': 'LOC', '4 septembre': 'TIME', 'AUXON': 'LOC', 'AFCA': 'ORG', '03 25 42 03 62': 'LOC', '18 h': 'TIME', 'Espace Jean Musy': 'LOC', 'Jean Musy': 'PER', '03 25 42 59 34': 'LOC', '24 août': 'TIME', "école primaire d'Estissac": 'LOC', 'Estissac': 'LOC', 'à partir de 7 h 30': 'TIME', 'Cyclo Club Othéen': 'ORG', '03 25 40 61 67': 'LOC', 'COUSSEGREY': 'LOC', 'univers': 'LOC', 'Univers': 'LOC', '355 €': 'AMOUNT', '03 25 70 69 35': 'LOC', 'www.laurier-rouge.com': 'LOC', 'Du 8 au 15 août': 'TIME', '8 septembre': 'TIME', 'SORMERY': 'LOC', 'Café Surprise': 'EVENT', '15 €': 'AMOUNT', "Couvent de l'Orée": 'ORG', '03 86 56 32 73': 'LOC', 'www.paciflore.com': 'LOC', 'Du 24 au 26 juin': 'TIME', 'Atelier de Sylvie Vernageau': 'LOC', 'après plusieur années': 'TIME', 'plusieurs années': 'AMOUNT', '9 mars 2018': 'TIME', 'M5S': 'ORG', 'le 2 novembre 2017': 'TIME', 'Belgique': 'LOC', 'le 5 décembre': 'TIME', 'justice espagnole': 'ORG', 'juges belges': 'FUNC', 'En 1952': 'TIME', 'CRS': 'FUNC', 'La semaine dernière': 'TIME', 'Royaume-Uni': 'LOC', '23 diplomates russes': 'AMOUNT', 'diplomates russes': 'FUNC', 'Quelques  mois': 'AMOUNT', 'Facebook': 'ORG', 'Google': 'ORG', 'AdWords': 'PROD', 'Les forces de défense et de sécu ...

# %%
sorted(dicoCasEN.items(), key=lambda t: t[0])
# Out:
# [('0 et 11 décembre', 'TIME'),
#  ('10 mars 2018', 'TIME'),
#  ('11 mars 2018', 'TIME'),
#  ('14 h', 'AMOUNT'),
#  ('14 mars 2018', 'TIME'),
#  ('15 septembre', 'TIME'),
#  ('15 €', 'AMOUNT'),
#  ('150 €', 'AMOUNT'),
#  ('16 juillet', 'TIME'),
#  ('18 ans', 'AMOUNT'),
#  ('2 semaines', 'AMOUNT'),
#  ('20 janvier 1994', 'TIME'),
#  ('20 novembre', 'TIME'),
#  ('22 ans', 'AMOUNT'),
#  ('23 juillet', 'TIME'),
#  ('23 juin au 7 juillet', 'TIME'),
#  ('24 août', 'TIME'),
#  ('250 années', 'AMOUNT'),
#  ('26 ans', 'AMOUNT'),
#  ('26 août', 'TIME'),
#  ('28 mai 2004', 'TIME'),
#  ('2ème jour', 'AMOUNT'),
#  ('3 mars 2018', 'TIME'),
#  ('3 €', 'AMOUNT'),
#  ('355 €', 'AMOUNT'),
#  ('4 mars', 'TIME'),
#  ('4 septembre', 'TIME'),
#  ('48 heures', 'AMOUNT'),
#  ('5 ans', 'AMOUNT'),
#  ('5 €', 'AMOUNT'),
#  ('500 euros', 'AMOUNT'),
#  ('5S', 'AMOUNT'),
#  ('8 mars 2018', 'TIME'),
#  ('8 septembre', 'TIME'),
#  ('9 h', 'AMOUNT'),
#  ('9 mars 2018', 'TIME'),
#  ('Actium', 'EVENT'),
#  ('Aden', 'LOC'),
#  ('Afrique', 'LOC'),
#  ('Andrew Wang', 'PER'),
#  ('Angleterre', 'LOC'),
#  ('Antilles', 'LOC'),
#  ('Aquitaine', 'LOC'),
#  ('Arabie', 'LOC'),
#  ('Armstrong', 'PER'),
#  ('Aube', 'LOC'),
#  ("Aujourd'hui", 'TIME'),
#  ('Bali', 'LOC'),
#  ('Balthazar', 'PER'),
#  ('Banque', 'ORG'),
#  ('Belgique', 'LOC'),
#  ('Blanche Maupas', 'PER'),
#  ('Bob Hope', 'PER'),
#  ('Bolloré', 'ORG'),
#  ('Bordeaux', 'LOC'),
#  ('Boston', 'LOC'),
#  ('Bourgogne', 'LOC'),
#  ('Budget', 'ORG'),
#  ('CRS', 'FUNC'),
#  ('Cabaret', 'ORG'),
#  ('Caen', 'LOC'),
#  ('Café', 'ORG'),
#  ('Californie', 'LOC'),
#  ('Cambridge', 'LOC'),
#  ('Cameroun', 'LOC'),
#  ('Canton', 'LOC'),
#  ('Carcassonne', 'LOC'),
#  ('Carthagène', 'LOC'),
#  ('Charasse', 'PER'),
#  ('Cherbourg-Octeville', 'LOC'),
#  ('Chine', 'LOC'),
#  ('Chroniques', 'PROD'),
#  ('Château de Guédelon', 'LOC'),
#  ('Collégiale Royale', 'LOC'),
#  ('Conseil', 'ORG'),
#  ('Créteil', 'LOC'),
#  ('Cyclo Club Othéen', 'ORG'),
#  ('Dans la matinée', 'TIME'),
#  ('Diderot', 'PER'),
#  ('Division', 'PER'),
#  ('Donald Hadley', 'PER'),
#  ('El Niño', 'PER'),
#  ('En 1952', 'TIME'),
#  ('En 1997', 'TIME'),
#  ('En 1998', 'TIME'),
#  ('En 2006', 'TIME'),
#  ('Espagne', 'LOC'),
#  ('Ethiopie', 'LOC'),
#  ('Europe', 'LOC'),
#  ('France', 'LOC'),
#  ('Francis Poullain', 'PER'),
#  ('François Mitterrand', 'PER'),
#  ('Front National', 'ORG'),
#  ('Fukushima', 'LOC'),
#  ('Fête du Cochon', 'EVENT'),
#  ('Gabi Heinze', 'PER'),
#  ('Galilée', 'LOC'),
#  ('Groenland', 'LOC'),
#  ('Guangdong', 'LOC'),
#  ('Halle Circulaire', 'LOC'),
#  ('Hollywood', 'LOC'),
#  ('Hong Kong', 'PER'),
#  ('Hugues Mingarelli', 'PER'),
#  ('Hyères', 'LOC'),
#  ('Inde', 'LOC'),
#  ('Ivan Netchiporko', 'PER'),
#  ('Jack London', 'PER'),
#  ('James Webb', 'PER'),
#  ('Japon', 'LOC'),
#  ('Jean', 'PER'),
#  ('Jean Musy', 'PER'),
#  ('Jeux', 'EVENT'),
#  ('Jeux olympiques', 'EVENT'),
#  ('Jiang Qing', 'PER'),
#  ('John Foxx', 'PER'),
#  ('Journées du Patrimoine', 'EVENT'),
#  ('Joy Division', 'PER'),
#  ('Juif', 'PER'),
#  ('Juillet 2011', 'TIME'),
#  ('Kafka', 'PER'),
#  ('LVMH', 'ORG'),
#  ('La semaine dernière', 'TIME'),
#  ('Le 17 mai 2004', 'TIME'),
#  ('Le soir', 'TIME'),
#  ('Le vendredi 2 mars 2018', 'TIME'),
#  ('Lisa', 'PER'),
#  ('Lorient', 'LOC'),
#  ('Louis Vuitton', 'PER'),
#  ('MAROLLES-SOUS-LIGNIERES', 'LOC'),
#  ('Mao Zedong', 'PER'),
#  ('Margaret Thatcher', 'PER'),
#  ('Maroc', 'LOC'),
#  ('Matthieu Normand', 'PER'),
#  ('Maurienne', 'LOC'),
#  ('Metallica', 'ORG'),
#  ('Meuse', 'LOC'),
#  ('Michael Faraday', 'PER'),
#  ('Michel', 'PER'),
#  ('Michel Charasse', 'PER'),
#  ('Michel Gondry', 'PER'),
#  ('Mont', 'LOC'),
#  ('Musée Colette', 'LOC'),
#  ('Musée du', 'LOC'),
#  ('Musée du Cidre', 'LOC'),
#  ('NASA', 'ORG'),
#  ('Narcisse Pigeon', 'PER'),
#  ('Nations unies', 'ORG'),
#  ('New York', 'LOC'),
#  ('Nicolas Collinet', 'PER'),
#  ('Nicolas Sarkozy', 'PER'),
#  ('Nigéria', 'LOC'),
#  ('Notre-Dame', 'PER'),
#  ('Object Management Group', 'ORG'),
#  ('Octobre 2011', 'TIME'),
#  ('Olav Tryggvason', 'PER'),
#  ('Oslo', 'LOC'),
#  ('Ouagadougou', 'LOC'),
#  ('Oxford', 'LOC'),
#  ('Pacifique', 'LOC'),
#  ('Palaiseau', 'LOC'),
#  ('Paris', 'LOC'),
#  ('Parlement', 'ORG'),
#  ('Paul Breisch', 'PER'),
#  ('Paul Vallier', 'PER'),
#  ('Pays', 'ORG'),
#  ('Philippe Borecek', 'PER'),
#  ('Pierre-Antoine Demachy', 'PER'),
#  ('Pékin', 'LOC'),
#  ('Quelques mois', 'AMOUNT'),
#  ('Renoir', 'PER'),
#  ('René Bousquet', 'PER'),
#  ('Rome', 'LOC'),
#  ("Royaume d'", 'ORG'),
#  ('Royaume-Uni', 'LOC'),
#  ('Russie', 'LOC'),
#  ('Révolution française', 'EVENT'),
#  ('Saint-Eustache', 'LOC'),
#  ('Saint-Jean', 'LOC'),
#  ('Saint-Lô', 'LOC'),
#  ('Saintes', 'LOC'),
#  ('Saturne', 'PER'),
#  ('Sept ans', 'AMOUNT'),
#  ('SoHO', 'LOC'),
#  ('Somalie', 'LOC'),
#  ('Stanley Kubrick', 'PER'),
#  ('Suisse', 'LOC'),
#  ('Sylvie Vernageau', 'PER'),
#  ('Taïwan', 'LOC'),
#  ('Terre', 'LOC'),
#  ('The Normal', 'ORG'),
#  ('Thionville', 'LOC'),
#  ('Théophile Maupas', 'PER'),
#  ('UE', 'LOC'),
#  ('USA', 'LOC'),
#  ('Une seconde', 'AMOUNT'),
#  ('Une soirée', 'AMOUNT'),
#  ('United Service Organizations', 'ORG'),
#  ("Villa de l'Extra", 'LOC'),
#  ('ancien Premier ministre', 'FUNC'),
#  ('ancien ministre socialiste', 'FUNC'),
#  ('archevêque', 'FUNC'),
#  ('armées', 'ORG'),
#  ('au 2 décembre', 'TIME'),
#  ("aujourd'hui", 'TIME'),
#  ('auparavant', 'TIME'),
#  ('auteur', 'FUNC'),
#  ('auteurs', 'FUNC'),
#  ('avant vingt heures quinze', 'TIME'),
#  ('avril', 'TIME'),
#  ('bientôt', 'TIME'),
#  ('boulanger', 'FUNC'),
#  ('boutique', 'ORG'),
#  ('capitale du', 'LOC'),
#  ('cent kilomètres', 'AMOUNT'),
#  ('ces 25 dernières', 'TIME'),
#  ('ces derniers jours', 'TIME'),
#  ('cette soirée', 'TIME'),
#  ('chaque année', 'TIME'),
#  ('chaque mois', 'TIME'),
#  ('chef', 'FUNC'),
#  ('chefs', 'FUNC'),
#  ('cinq minutes', 'AMOUNT'),
#  ('cinquante francs', 'AMOUNT'),
#  ('conceptrice', 'FUNC'),
#  ('conducteur', 'FUNC'),
#  ('consortium', 'ORG'),
#  ('de 10 h à 18 h', 'TIME'),
#  ('de 1930 à 1942', 'TIME'),
#  ('de Noël', 'TIME'),
#  ('des saisons', 'AMOUNT'),
#  ('des soirées', 'AMOUNT'),
#  ('deux cent quatre-vingt huit kilomètres', 'AMOUNT'),
#  ('dix-neuf heures trente', 'AMOUNT'),
#  ('dix-sept kilomètres', 'AMOUNT'),
#  ('documentaires', 'PROD'),
#  ('du 3 mars', 'TIME'),
#  ("dès le mois d' avril 1915", 'TIME'),
#  ('dès septembre 2004', 'TIME'),
#  ('délégués', 'FUNC'),
#  ('département de la', 'LOC'),
#  ('département du', 'LOC'),
#  ('département français des', 'ORG'),
#  ('en 1922', 'TIME'),
#  ('en 1933', 'TIME'),
#  ('en 1962', 'TIME'),
#  ('en 1989', 'TIME'),
#  ('en 1994', 'TIME'),
#  ('en 1996', 'TIME'),
#  ('en 2000', 'TIME'),
#  ('en 2011', 'TIME'),
#  ('en novembre de la même année', 'TIME'),
#  ('entre 12 h et 14 h', 'TIME'),
#  ('entreprise', 'ORG'),
#  ('entreprises', 'ORG'),
#  ('foreuse', 'FUNC'),
#  ('forêt', 'LOC'),
#  ('gendarmes', 'FUNC'),
#  ('général', 'FUNC'),
#  ('jardin', 'ORG'),
#  ('jardins', 'ORG'),
#  ('jeux', 'EVENT'),
#  ('joueurs', 'FUNC'),
#  ('juges', 'FUNC'),
#  ('justice', 'ORG'),
#  ("l'après-midi", 'TIME'),
#  ('la journée', 'TIME'),
#  ('la nuit', 'TIME'),
#  ('laboratoires', 'ORG'),
#  ('le 11 avril 1814', 'TIME'),
#  ('le 1er janvier 1811', 'TIME'),
#  ('le 2 novembre 2017', 'TIME'),
#  ('le 2 octobre 2006', 'TIME'),
#  ('le 20 mars 2018', 'TIME'),
#  ('le 5 décembre', 'TIME'),
#  ('le 6 septembre 1764', 'TIME'),
#  ('le jour', 'TIME'),
#  ('le mois précédent', 'TIME'),
#  ('le siècle', 'TIME'),
#  ('le soir', 'TIME'),
#  ('les journées', 'TIME'),
#  ('les trente derniers', 'TIME'),
#  ('lutteur', 'FUNC'),
#  ('lycée', 'ORG'),
#  ('magazine', 'PROD'),
#  ('maintenant', 'TIME'),
#  ('marchand', 'FUNC'),
#  ('marines', 'ORG'),
#  ('mondial', 'EVENT'),
#  ('monts', 'LOC'),
#  ('mère', 'FUNC'),
#  ('médecin', 'FUNC'),
#  ('météorologues', 'FUNC'),
#  ('null', 'PER'),
#  ('océan', 'LOC'),
#  ('patineurs', 'FUNC'),
#  ('patron', 'FUNC'),
#  ('peintre', 'FUNC'),
#  ('pilote', 'FUNC'),
#  ('plaine', 'LOC'),
#  ('plateau', 'LOC'),
#  ('plus tôt', 'TIME'),
#  ('plusieurs décennies', 'AMOUNT'),
#  ('portière', 'FUNC'),
#  ('pour ce moment', 'TIME'),
#  ('pour cette nouvelle année', 'TIME'),
#  ("pour l' instant", 'TIME'),
#  ('premiers livres', 'AMOUNT'),
#  ('premières années', 'AMOUNT'),
#  ('presse', 'ORG'),
#  ('procureur', 'FUNC'),
#  ('professeurs', 'FUNC'),
#  ('père', 'FUNC'),
#  ('quarante-neuf kilomètres', 'AMOUNT'),
#  ('quatre minutes', 'AMOUNT'),
#  ('quatre-vingt dix-neuf kilomètres', 'AMOUNT'),
#  ('quatre-vingt onze kilomètres', 'AMOUNT'),
#  ('quelques années', 'AMOUNT'),
#  ('quelques francs', 'AMOUNT'),
#  ('rivière', 'LOC'),
#  ('scientifiques', 'FUNC'),
#  ('sommet', 'LOC'),
#  ('surface', 'LOC'),
#  ('tous les jours', 'TIME'),
#  ('tout an', 'TIME'),
#  ('trois minutes', 'AMOUNT'),
#  ('un instant', 'AMOUNT'),
#  ('un livre', 'AMOUNT'),
#  ('université', 'ORG'),
#  ('vers quatre heures', 'TIME'),
#  ('vers vingt heures', 'TIME'),
#  ('ville de', 'LOC'),
#  ('vingt-et-unième siècle', 'TIME'),
#  ('vingt-quatre kilomètres', 'AMOUNT'),
#  ('vingt-sept kilomètres', 'AMOUNT'),
#  ('vingt-six kilomètres', 'AMOUNT'),
#  ('vingt-trois kilomètres', 'AMOUNT'),
#  ('voyageur', 'FUNC'),
#  ('À cette heure', 'TIME'),
#  ('Égypte', 'LOC'),
#  ('États-Unis', 'LOC'),
#  ('à', 'TIME'),
#  ('à 17 h', 'TIME'),
#  ('à 18 h', 'TIME'),
#  ('à 19 h', 'TIME'),
#  ('à 20 h 30', 'TIME'),
#  ('à ce moment', 'TIME'),
#  ('à partir de 1950', 'TIME'),
#  ('à partir de 7 h 30', 'TIME'),
#  ('école', 'ORG'),
#  ('école primaire', 'ORG'),
#  ('écrivains', 'FUNC'),
#  ('église', 'LOC'),
#  ('élevage', 'ORG'),
#  ('équipe', 'ORG'),
#  ('évêque', 'FUNC'),
#  ('île', 'LOC'),
#  ('îles', 'LOC')]

# %%
sorted(dicoMano.items(), key=lambda t: t[0])
# Out:
# [('03 25 40 61 67', 'LOC'),
#  ('03 25 42 03 62', 'LOC'),
#  ('03 25 42 10 46', 'LOC'),
#  ('03 25 42 59 34', 'LOC'),
#  ('03 25 43 22 10', 'LOC'),
#  ('03 25 43 92 26', 'LOC'),
#  ('03 25 70 03 05', 'LOC'),
#  ('03 25 70 69 35', 'LOC'),
#  ('03 25 76 01 38', 'LOC'),
#  ('03 25 76 88 78', 'LOC'),
#  ('03 25 80 75 69', 'LOC'),
#  ('03 26 55 71 80', 'LOC'),
#  ('03 86 56 32 73', 'LOC'),
#  ('06 01 71 82 17', 'LOC'),
#  ('06 75 15 06 14', 'LOC'),
#  ('06 79 07 79 25', 'LOC'),
#  ('06 82 96 92 24', 'LOC'),
#  ('10 Downing Street', 'LOC'),
#  ('10 et 11 décembre', 'TIME'),
#  ('10 mars 2018', 'TIME'),
#  ('10%', 'AMOUNT'),
#  ('100.000 naissances', 'AMOUNT'),
#  ('11 mars 2018', 'TIME'),
#  ('110 décès', 'AMOUNT'),
#  ('13 responsables de la représentation diplomatique espagnole', 'AMOUNT'),
#  ('14 mars 2018', 'TIME'),
#  ('15 septembre', 'TIME'),
#  ('15 €', 'AMOUNT'),
#  ('150 €', 'AMOUNT'),
#  ('16 juillet', 'TIME'),
#  ('175 films', 'AMOUNT'),
#  ('18 ans', 'AMOUNT'),
#  ('18 h', 'TIME'),
#  ('19 h', 'TIME'),
#  ('1979 - 1980', 'TIME'),
#  ('1980 - 1981', 'TIME'),
#  ('1986', 'TIME'),
#  ('1997', 'TIME'),
#  ('2', 'AMOUNT'),
#  ('2 flacons', 'AMOUNT'),
#  ('2 rue du four', 'LOC'),
#  ('2 semaines', 'AMOUNT'),
#  ('20 h 30', 'TIME'),
#  ('20 janvier 1994', 'TIME'),
#  ('20 novembre', 'TIME'),
#  ('2000', 'TIME'),
#  ('2002', 'TIME'),
#  ('2018', 'TIME'),
#  ('22 ans', 'AMOUNT'),
#  ('22 rue Largentier', 'LOC'),
#  ('23 diplomates russes', 'AMOUNT'),
#  ('23 juillet', 'TIME'),
#  ('23 juin au 7 juillet', 'TIME'),
#  ('24 août', 'TIME'),
#  ('250 années', 'AMOUNT'),
#  ('26 ans', 'AMOUNT'),
#  ('26 août', 'TIME'),
#  ('28 mai 2004', 'TIME'),
#  ('28 personnes mortes', 'AMOUNT'),
#  ('2ème jour du Marché du Livre', 'TIME'),
#  ('3 mars 2018', 'TIME'),
#  ('3 €', 'AMOUNT'),
#  ('355 €', 'AMOUNT'),
#  ('39 adhérents', 'AMOUNT'),
#  ('4 enfants sur 100', 'AMOUNT'),
#  ('4 mars 2018', 'TIME'),
#  ('4 septembre', 'TIME'),
#  ('41ème fête du cidre', 'EVENT'),
#  ('48 heures', 'AMOUNT'),
#  ('5 ans', 'AMOUNT'),
#  ('5 sauvageonnes comestibles', 'AMOUNT'),
#  ('5 x 1 flacon', 'AMOUNT'),
#  ('5 €', 'AMOUNT'),
#  ('500 euros', 'AMOUNT'),
#  ('70 %', 'AMOUNT'),
#  ('723 premières années', 'AMOUNT'),
#  ('723 premières années de Rome', 'TIME'),
#  ('8 assaillants', 'AMOUNT'),
#  ('8 mars 2018', 'TIME'),
#  ('8 septembre', 'TIME'),
#  ('80 blessés', 'AMOUNT'),
#  ('80%', 'AMOUNT'),
#  ('9 mars 2018', 'TIME'),
#  ('AFCA', 'ORG'),
#  ('AFP', 'ORG'),
#  ('AIX-EN-OTHE', 'LOC'),
#  ('AP', 'PROD'),
#  ('AUXON', 'LOC'),
#  ('Accident nucléaire de Fukushima', 'EVENT'),
#  ('Aclasta', 'PROD'),
#  ('Actium', 'LOC'),
#  ('AdWords', 'PROD'),
#  ('Aden', 'LOC'),
#  ('Adrian', 'PER'),
#  ('Afrique', 'LOC'),
#  ('Agüero', 'PER'),
#  ('Akadêmia', 'ORG'),
#  ('Alexandre', 'PER'),
#  ('Algérie', 'LOC'),
#  ('Andrew Wang', 'PER'),
#  ('Angiox', 'PROD'),
#  ('Angleterre', 'LOC'),
#  ('Antilles', 'LOC'),
#  ('Aquitaine', 'LOC'),
#  ('Arabie', 'LOC'),
#  ('Arago', 'PER'),
#  ('Armand Riberolles', 'PER'),
#  ('Armstrong', 'PER'),
#  ('Arrhenius', 'PER'),
#  ('Atelier de Sylvie Vernageau', 'LOC'),
#  ("Au fil de l'Ours, dans les pas de Renoir", 'EVENT'),
#  ('Au sud de la frontière', 'PROD'),
#  ('Aube', 'LOC'),
#  ("Aujourd'hui", 'TIME'),
#  ('Avant la Révolution française', 'TIME'),
#  ('Avranches', 'LOC'),
#  ('BERULLE', 'LOC'),
#  ('BOUILLY', 'LOC'),
#  ('Bali', 'LOC'),
#  ('Ballard', 'PER'),
#  ('Balthazar', 'PER'),
#  ("Banque d'Indochine", 'ORG'),
#  ('Belgique', 'LOC'),
#  ('Beloved', 'PROD'),
#  ('Besse', 'PER'),
#  ('Blanche Maupas', 'PER'),
#  ('Bob Hope', 'PER'),
#  ('Bolloré', 'PER'),
#  ('Bordeaux', 'LOC'),
#  ('Boson', 'PER'),
#  ('Boston', 'LOC'),
#  ('Bouches-du-Rhône', 'LOC'),
#  ('Bourgogne', 'LOC'),
#  ('Bretagne', 'LOC'),
#  ('Burkina-Faso', 'LOC'),
#  ('Bérulle', 'LOC'),
#  ('CCAS', 'ORG'),
#  ('CFB', 'ORG'),
#  ('CGT', 'ORG'),
#  ('CHAOURCE', 'LOC'),
#  ('COUSSEGREY', 'LOC'),
#  ('CRS', 'FUNC'),
#  ('Caen', 'LOC'),
#  ('Café Surprise', 'EVENT'),
#  ('Californie', 'LOC'),
#  ('Cambridge', 'LOC'),
#  ('Cameroun', 'LOC'),
#  ('Canal +', 'ORG'),
#  ('Cancale', 'LOC'),
#  ('Canton', 'LOC'),
#  ('Carcassonne', 'LOC'),
#  ('Carthagène', 'LOC'),
#  ('Cavalaire', 'LOC'),
#  ('Cavalaire Pardigon', 'LOC'),
#  ('Centrale féline Belge', 'ORG'),
#  ('Certains patineurs', 'AMOUNT'),
#  ('Championnats du monde junior de short-track 2018', 'EVENT'),
#  ('Charasse', 'PER'),
#  ('Charvet', 'PER'),
#  ('Chausey', 'LOC'),
#  ('Cherbourg-Octeville', 'LOC'),
#  ('Chine', 'LOC'),
#  ("Chroniques de l'oiseau à ressort", 'PROD'),
#  ('Château de Guédelon', 'LOC'),
#  ("Club des Anciens et de amis d'Aix", 'ORG'),
#  ('Clémence', 'PER'),
#  ('Collégiale Royale Sainte-Marthe', 'LOC'),
#  ('Colonies', 'ORG'),
#  ('Comité des fêtes', 'ORG'),
#  ('Commission', 'ORG'),
#  ('Commission de la Culture', 'ORG'),
#  ('Concert', 'EVENT'),
#  ("Concert d'orgue", 'EVENT'),
#  ('Conseil', 'ORG'),
#  ('Costebelle', 'LOC'),
#  ('Coutances', 'LOC'),
#  ("Couvent de l'Orée", 'ORG'),
#  ('Créteil', 'LOC'),
#  ('Curiosity', 'PROD'),
#  ('Cyclo Club Othéen', 'ORG'),
#  ('DGI', 'ORG'),
#  ('DMCA', 'PROD'),
#  ('Daesh', 'ORG'),
#  ('Dans la matinée', 'TIME'),
#  ('Deux temps', 'AMOUNT'),
#  ('Diderot', 'PER'),
#  ('Dieu', 'PER'),
#  ('Direction générale des impôts', 'ORG'),
#  ('Donald Hadley', 'PER'),
#  ('Du 24 au 26 juin', 'TIME'),
#  ('Du 8 au 15 août', 'TIME'),
#  ('Du 9 au 11 septembre', 'TIME'),
#  ('EAUX-PUISEAUX', 'LOC'),
#  ('ERVY-LE-CHATEL', 'LOC'),
#  ('ESSOYES', 'LOC'),
#  ('ESTISSAC', 'LOC'),
#  ('El Niño', 'LOC'),
#  ('Elizabeth II', 'PER'),
#  ('En 1209', 'TIME'),
#  ('En 1952', 'TIME'),
#  ('En 1997', 'TIME'),
#  ('En 1998', 'TIME'),
#  ('En 2006', 'TIME'),
#  ('Ervy-le-Châtel', 'LOC'),
#  ('Espace Jean Musy', 'LOC'),
#  ('Espagne', 'LOC'),
#  ('Estissac', 'LOC'),
#  ('Etats-Unis', 'LOC'),
#  ('Ethiopie', 'LOC'),
#  ('Europe', 'LOC'),
#  ('Facebook', 'ORG'),
#  ('Festival en Othe', 'EVENT'),
#  ('Feux de la Saint-Jean', 'EVENT'),
#  ('Florent', 'PER'),
#  ("Fonds des Nations unies pour l'enfance", 'ORG'),
#  ('France', 'LOC'),
#  ('Francis Poullain', 'PER'),
#  ('François Mitterrand', 'PER'),
#  ('Fringe', 'PROD'),
#  ('Front National', 'ORG'),
#  ('Fukushima', 'LOC'),
#  ('Fête du Cochon', 'EVENT'),
#  ('Fête du tilleul centenaire', 'EVENT'),
#  ('Gabi Heinze', 'PER'),
#  ('Galilée', 'PER'),
#  ('Giens', 'LOC'),
#  ('Glacier Perito Moreno', 'LOC'),
#  ('Google', 'ORG'),
#  ('Granville', 'LOC'),
#  ('Groenland', 'LOC'),
#  ('Guangdong', 'LOC'),
#  ('Halle Circulaire', 'LOC'),
#  ('Hennessy', 'PER'),
#  ('Hollywood', 'LOC'),
#  ('Hong Kong', 'LOC'),
#  ('Hubble', 'PROD'),
#  ('Hugues Mingarelli', 'PER'),
#  ('Hyères', 'LOC'),
#  ('IRS', 'ORG'),
#  ('Inde', 'LOC'),
#  ('Ivan Netchiporko', 'PER'),
#  ('Jack London', 'PER'),
#  ('James Webb', 'PER'),
#  ('Japon', 'LOC'),
#  ('Jean Musy', 'PER'),
#  ('Jean-Claude Méry', 'PER'),
#  ('Jeux Paralympiques', 'EVENT'),
#  ('Jeux olympiques', 'EVENT'),
#  ('Jiang Qing', 'PER'),
#  ('John Foxx', 'PER'),
#  ('John Sulston', 'PER'),
#  ('Joscelin', 'PER'),
#  ('Journées du Patrimoine', 'EVENT'),
#  ('Joy Division', 'PER'),
#  ('Juillet 2011', 'TIME'),
#  ('Juvisy', 'LOC'),
#  ('Kafka', 'PER'),
#  ('Kafka sur le rivage', 'PROD'),
#  ("L'Almanarre", 'LOC'),
#  ("L'Ayguade", 'LOC'),
#  ('LIGNIERES', 'LOC'),
#  ('LVMH', 'ORG'),
#  ('LVMH - Moët Hennessy Louis Vuitton', 'ORG'),
#  ('La Capte', 'LOC'),
#  ('La course du mouton sauvage', 'PROD'),
#  ('La semaine dernière', 'TIME'),
#  ('Lance et compte', 'PROD'),
#  ('Le 17 mai 2004', 'TIME'),
#  ('Le Figaro', 'PROD'),
#  ('Le Fusillé', 'PROD'),
#  ('Le Pyanet', 'LOC'),
#  ('Le lendemain', 'TIME'),
#  ('Le soir', 'TIME'),
#  ('Le vendredi 2 mars 2018', 'TIME'),
#  ('Leeuwarden', 'LOC'),
#  ('Les Borrels', 'LOC'),
#  ('Les Ombelles', 'ORG'),
#  ("Les Salins-d'Hyères", 'LOC'),
#  ('Les Sentiers de la gloire', 'PROD'),
#  ('Les forces de défense et de sécurité burkinabés', 'PER'),
#  ("Ligue des droits de l'Homme", 'ORG'),
#  ('Lisa', 'PER'),
#  ('Locke', 'PER'),
#  ('Lorient', 'LOC'),
#  ('Louis Vuitton', 'ORG'),
#  ('Louis XV', 'PER'),
#  ('Lubljana', 'LOC'),
#  ('M. Christian Langlois', 'PER'),
#  ('M. Monnet Pierre', 'PER'),
#  ('M. Patrice Lanini', 'PER'),
#  ('M5S', 'ORG'),
#  ('MARAYE-EN-OTHE', 'LOC'),
#  ('MAROLLES-SOUS-LIGNIERES', 'LOC'),
#  ('Ma mère', 'PROD'),
#  ('Mao Zedong', 'PER'),
#  ('Maraye Pour Tous', 'ORG'),
#  ('Marché de Noël', 'EVENT'),
#  ('Marché du Livre', 'EVENT'),
#  ('Margaret Thatcher', 'PER'),
#  ('Maroc', 'LOC'),
#  ('Mars', 'LOC'),
#  ('Massy -- Palaiseau', 'LOC'),
#  ('Massy TGV', 'LOC'),
#  ('Matthieu Normand', 'PER'),
#  ('Maxwell', 'PER'),
#  ('Metallica', 'PER'),
#  ('Metro-Goldwyn-Mayer', 'ORG'),
#  ('Meuse', 'LOC'),
#  ('Michael Faraday', 'PER'),
#  ('Michel Charasse', 'PER'),
#  ('Michel Gondry', 'PER'),
#  ('Monsieur Gavard', 'PER'),
#  ('Mont-Saint-Michel', 'LOC'),
#  ('Morbihan', 'LOC'),
#  ('Morges', 'LOC'),
#  ('Morrison', 'PER'),
#  ('Moët', 'PER'),
#  ('Moët Hennessy', 'ORG'),
#  ('Musée Colette', 'LOC'),
#  ('Musée du Cidre', 'LOC'),
#  ('Musée du Louvre', 'ORG'),
#  ('NASA', 'ORG'),
#  ('Narcisse Pigeon', 'PER'),
#  ('Nations unies', 'ORG'),
#  ('New York', 'LOC'),
#  ('New York Times', 'PROD'),
#  ('Nicolas Collinet', 'PER'),
#  ('Nicolas Sarkozy', 'PER'),
#  ('Nigéria', 'LOC'),
#  ('Nord de la Chine', 'LOC'),
#  ('Notre-Dame', 'LOC'),
#  ('OMG', 'ORG'),
#  ('OPAC', 'ORG'),
#  ('Object Management Group', 'ORG'),
#  ('Octobre 2011', 'TIME'),
#  ("Office public d'aménagement et de construction de la ville de Paris",
#   'ORG'),
#  ('Olav Tryggvason', 'PER'),
#  ('Olkaloo', 'LOC'),
#  ('Oslo', 'LOC'),
#  ('Otton I er', 'PER'),
#  ('Ouagadougou', 'LOC'),
#  ('Oxford', 'LOC'),
#  ('PALIS', 'LOC'),
#  ('Pacifique', 'LOC'),
#  ('Pacte andin', 'PROD'),
#  ('Paget', 'PER'),
#  ('Palaiseau', 'LOC'),
#  ('Paris', 'LOC'),
#  ('Parlement', 'ORG'),
#  ('Passaic', 'LOC'),
#  ("Patrimoine mondial de l'UNESCO", 'ORG'),
#  ('Paul Breisch', 'PER'),
#  ('Paul Vallier', 'PER'),
#  ('Pauline', 'PER'),
#  ("Pays d'Armance", 'LOC'),
#  ('Performing Live', 'PROD'),
#  ('Perito Moreno', 'PER'),
#  ('Philippe Borecek', 'PER'),
#  ('Pierre-Antoine Demachy', 'PER'),
#  ('Plus de cinquante wikimédien.ne.s', 'AMOUNT'),
#  ('Practicing Philosophy', 'PROD'),
#  ('Premier ministre', 'FUNC'),
#  ('Première Guerre mondiale', 'EVENT'),
#  ('Pékin', 'LOC'),
#  ('Quelques  mois', 'AMOUNT'),
#  ('Quelques mois', 'AMOUNT'),
#  ('Quenu', 'PER'),
#  ('RACINES', 'LOC'),
#  ('Rapides de la Meuse', 'ORG'),
#  ('Renoir', 'PER'),
#  ('René Bousquet', 'PER'),
#  ('Reuilly', 'LOC'),
#  ('Reuilly - Diderot', 'LOC'),
#  ('Rome', 'LOC'),
#  ("Royaume d'Egypte", 'ORG'),
#  ('Royaume-Uni', 'LOC'),
#  ('Russie', 'LOC'),
#  ('Récital de Piano 4 mains', 'EVENT'),
#  ('Révolution française', 'EVENT'),
#  ('SORMERY', 'LOC'),
#  ('Saint-Eustache', 'LOC'),
#  ('Saint-Jean-de-Maurienne', 'LOC'),
#  ('Saint-Lô', 'LOC'),
#  ('Saintes', 'LOC'),
#  ('Saturne', 'LOC'),
#  ('Sept ans', 'AMOUNT'),
#  ('Sept ans après le tsunami', 'TIME'),
#  ('Sesame Street', 'PROD'),
#  ('Shenzhen', 'LOC'),
#  ('Shusterman', 'PER'),
#  ('SoHO', 'PROD'),
#  ('Soirée « Entre France et Russie »', 'EVENT'),
#  ('Somalie', 'LOC'),
#  ('Souain', 'LOC'),
#  ('Soyez sympas, rembobinez', 'PROD'),
#  ('Stanley Kubrick', 'PER'),
#  ('Stop USA', 'PROD'),
#  ('Strasbourg', 'LOC'),
#  ('Suisse', 'LOC'),
#  ('Surface and Depth', 'PROD'),
#  ('Sylvie Vernageau', 'PER'),
#  ('TGV', 'PROD'),
#  ('Tarascon', 'LOC'),
#  ('Tardi', 'PER'),
#  ('Taïwan', 'LOC'),
#  ('Terre', 'LOC'),
#  ('The Normal', 'PER'),
#  ('Thionville', 'LOC'),
#  ('Thionville FC', 'ORG'),
#  ('Théophile Maupas', 'PER'),
#  ('Tiangong-1', 'PROD'),
#  ('Turk Murphy', 'PER'),
#  ('Téléthon', 'EVENT'),
#  ('UCLA Bruins', 'ORG'),
#  ('UE', 'ORG'),
#  ('UNESCO', 'ORG'),
#  ('USA', 'LOC'),
#  ('USC Trojans', 'ORG'),
#  ('United Service Organizations', 'ORG'),
#  ('Univers', 'LOC'),
#  ('VAUCHASSIS', 'LOC'),
#  ('Valve', 'ORG'),
#  ('Verdun la vie', 'PROD'),
#  ('Verdunois', 'PER'),
#  ("Villa de l'Extra", 'ORG'),
#  ('XXème siècle', 'TIME'),
#  ('accord de Carthagène', 'PROD'),
#  ("accords sur l'énergie atomique", 'PROD'),
#  ("accords sur le charbon et l'acier", 'PROD'),
#  ('ancien Premier ministre', 'FUNC'),
#  ('après plusieur années', 'TIME'),
#  ('archevêque', 'FUNC'),
#  ('archevêque de Bordeaux', 'FUNC'),
#  ('arrondissement de Leeuwarden', 'LOC'),
#  ('artistes', 'FUNC'),
#  ('au 17 e siècle', 'TIME'),
#  ('au 2 décembre', 'TIME'),
#  ("aujourd'hui", 'TIME'),
#  ('auteur', 'FUNC'),
#  ('avant vingt heures quinze', 'TIME'),
#  ('bande des Quatre', 'PER'),
#  ("bataille d'Actium", 'EVENT'),
#  ('boulanger', 'FUNC'),
#  ("brevet de pilote d'avion", 'PROD'),
#  ('caporaux', 'FUNC'),
#  ('cathédrale de Luxembourg', 'LOC'),
#  ('cent kilomètres', 'AMOUNT'),
#  ('cent sous', 'AMOUNT'),
#  ('cents sous', 'AMOUNT'),
#  ('ces derniers jours', 'TIME'),
#  ('cette nouvelle année', 'TIME'),
#  ('cette soirée', 'TIME'),
#  ('cinquante francs', 'AMOUNT'),
#  ('comité des fêtes', 'ORG'),
#  ('commis', 'FUNC'),
#  ('conceptrice de robe', 'FUNC'),
#  ('concile', 'EVENT'),
#  ('conducteur', 'FUNC'),
#  ("corne de l'Afrique", 'LOC'),
#  ('croyants', 'PER'),
#  ('dans les prochaines 48 heures', 'TIME'),
#  ('de 10 h à 18 h', 'TIME'),
#  ('de 14 h 30 à 18 h', 'TIME'),
#  ('de 1930 à 1942', 'TIME'),
#  ('de 1969', 'TIME'),
#  ('de 9 h 30 à 12 h 30', 'TIME'),
#  ('de 9 h 30 à 18 h', 'TIME'),
#  ('delta de la rivière des Perles', 'LOC'),
#  ('delta du Nord de la Chine', 'LOC'),
#  ('depuis oui cinq minutes', 'AMOUNT'),
#  ('deux cent quatre-vingt huit kilomètres', 'AMOUNT'),
#  ('deux femmes', 'AMOUNT'),
#  ('deux ouvriers', 'AMOUNT'),
#  ('deux techniques', 'AMOUNT'),
#  ('deux tranches de galantine', 'AMOUNT'),
#  ('diplomates russes', 'FUNC'),
#  ('directeur artistique', 'FUNC'),
#  ("directeur de la Banque d'Indochine", 'FUNC'),
#  ('dix mille', 'AMOUNT'),
#  ('dix millions', 'AMOUNT'),
#  ('dix-neuf heures trente', 'TIME'),
#  ('dix-sept kilomètres', 'AMOUNT'),
#  ('docteurs', 'FUNC'),
#  ('du 3 mars', 'TIME'),
#  ('du XVII e sicèle', 'TIME'),
#  ("duc d'Aquitaine", 'FUNC'),
#  ("dès le mois d'avril 1915", 'TIME'),
#  ('dès septembre 2004', 'TIME'),
#  ('début avril', 'TIME'),
#  ('délégués syndicaux', 'FUNC'),
#  ('département de la Frise', 'LOC'),
#  ('en -31', 'TIME'),
#  ('en 1922', 'TIME'),
#  ('en 1933', 'TIME'),
#  ('en 1962', 'TIME'),
#  ('en 1989', 'TIME'),
#  ('en 1994', 'TIME'),
#  ('en 1996', 'TIME'),
#  ('en 2000', 'TIME'),
#  ('en 2011', 'TIME'),
#  ('en novembre de la même année', 'TIME'),
#  ('entre 12 h et 14 h', 'TIME'),
#  ('foyer familial', 'LOC'),
#  ("fusillés pour l'exemple", 'PER'),
#  ('gendarmes', 'FUNC'),
#  ('groupe Bolloré', 'ORG'),
#  ('groupe EDD', 'ORG'),
#  ('http://villa-de-l-extra.skyrock.com/', 'LOC'),
#  ('jeudi', 'TIME'),
#  ("journée mondiale des droits de l'enfant", 'EVENT'),
#  ('juge', 'FUNC'),
#  ('juges belges', 'FUNC'),
#  ('juges français', 'FUNC'),
#  ("jusqu'à début 2006", 'TIME'),
#  ('justice espagnole', 'ORG'),
#  ("l'après-midi", 'TIME'),
#  ("l'état-major des armées", 'FUNC'),
#  ('la Boule Palisienne', 'ORG'),
#  ('lavoir des boulins', 'LOC'),
#  ('le 11 avril 1814', 'TIME'),
#  ('le 1er janvier 1811', 'TIME'),
#  ('le 2 novembre 2017', 'TIME'),
#  ('le 2 octobre 2006', 'TIME'),
#  ('le 20 mars 2018', 'TIME'),
#  ('le 5 décembre', 'TIME'),
#  ('le 6 septembre 1764', 'TIME'),
#  ('le boulevard Diderot', 'LOC'),
#  ('le mois précédent', 'TIME'),
#  ('le soir', 'TIME'),
#  ('le vingt-et-unième siècle', 'TIME'),
#  ('les cinquante premiers livres', 'AMOUNT'),
#  ('les maquiladoras', 'LOC'),
#  ('lutteur', 'FUNC'),
#  ('lycée Arago', 'ORG'),
#  ('madame Lecoeur', 'PER'),
#  ('mademoiselle Saget', 'PER'),
#  ('maintenant', 'TIME'),
#  ('marchand', 'FUNC'),
#  ('marchand de vin', 'FUNC'),
#  ('meilleur roman de ces 25 dernières années', 'PROD'),
#  ('ministre des Colonies', 'FUNC'),
#  ('ministre socialiste du Budget', 'FUNC'),
#  ('monsieur Lebigre', 'PER'),
#  ('monts Oural', 'LOC'),
#  ('médecin', 'FUNC'),
#  ('météorologues', 'FUNC'),
#  ('parquet de Créteil', 'ORG'),
#  ('patineurs', 'FUNC'),
#  ('patron', 'FUNC'),
#  ('peintre', 'FUNC'),
#  ('place Caroline', 'LOC'),
#  ('place Notre-Dame', 'LOC'),
#  ('place Paul Vallier', 'LOC'),
#  ('plaine du Nord de la Chine', 'LOC'),
#  ('plusieurs années', 'AMOUNT'),
#  ('plusieurs décennies', 'AMOUNT'),
#  ('point zéro des routes de France', 'LOC'),
#  ('port fortifié de Morges', 'LOC'),
#  ('portière', 'FUNC'),
#  ('poëte', 'FUNC'),
#  ('prix Nobel de médecine', 'PROD'),
#  ('procureur', 'FUNC'),
#  ('producteur', 'FUNC'),
#  ('professeurs', 'FUNC'),
#  ('promoteur', 'FUNC'),
#  ('protecteur de la Bourgogne', 'FUNC'),
#  ('quarante-neuf kilomètres', 'AMOUNT'),
#  ('quatre minutes', 'AMOUNT'),
#  ('quatre-vingt dix-neuf kilomètres', 'AMOUNT'),
#  ('quatre-vingt onze kilomètres', 'AMOUNT'),
#  ('quelques années', 'AMOUNT'),
#  ('quelques années auparavant', 'TIME'),
#  ('quelques francs', 'AMOUNT'),
#  ('reine', 'FUNC'),
#  ('représentation diplomatique espagnole', 'FUNC'),
#  ('risédronate', 'PROD'),
#  ('rivière des Perles', 'LOC'),
#  ('rue  de  Strasbourg', 'LOC'),
#  ('rue Largentier', 'LOC'),
#  ('rue Montorgueil', 'LOC'),
#  ('rue du four', 'LOC'),
#  ('salle des fêtes', 'LOC'),
#  ('scientifiques', 'FUNC'),
#  ('station spatiale chinoise Tiangong - 1', 'PROD'),
#  ('tablettière', 'FUNC'),
#  ('tous les jours', 'TIME'),
#  ('trente derniers', 'AMOUNT'),
#  ('trois minutes', 'AMOUNT'),
#  ('trois périodes', 'AMOUNT'),
#  ('télescope spatial James Webb', 'PROD'),
#  ('univers', 'LOC'),
#  ('vers quatre heures', 'TIME'),
#  ('vers vingt heures ou dix-neuf heures trente', 'TIME'),
#  ('vieille Méhudin', 'PER'),
#  ('vingt heures quinze', 'TIME'),
#  ('vingt-neuf docteurs', 'AMOUNT'),
#  ('vingt-quatre kilomètres', 'AMOUNT'),
#  ('vingt-sept kilomètres', 'AMOUNT'),
#  ('vingt-six kilomètres', 'AMOUNT'),
#  ('vingt-trois kilomètres', 'AMOUNT'),
#  ('www.akademia.fr', 'LOC'),
#  ('www.festivalenothe.org', 'LOC'),
#  ('www.laurier-rouge.com', 'LOC'),
#  ('www.lesombelles.com', 'LOC'),
#  ('www.paciflore.com', 'LOC'),
#  ('À cette heure avancée de la nuit', 'TIME'),
#  ('Égypte', 'LOC'),
#  ('États-Unis', 'LOC'),
#  ('à 17 h', 'TIME'),
#  ('à 19 h', 'TIME'),
#  ('à 20 h 30', 'TIME'),
#  ('à cette date', 'TIME'),
#  ('à partir de 1950', 'TIME'),
#  ('à partir de 7 h 30', 'TIME'),
#  ("école primaire d'Estissac", 'LOC'),
#  ('écrivains', 'FUNC'),
#  ('église', 'LOC'),
#  ('église Saint Laurent', 'LOC'),
#  ('équateur', 'LOC'),
#  ('équipe de France', 'PER'),
#  ('évêque', 'FUNC'),
#  ('évêque de Saintes', 'FUNC')]

# %%
def compare(first, second):
    commun = {}
    sharedKeys = set(first.keys()).intersection(second.keys())
    print("D'abord, toutes les clés identiques avec valeurs identiques : ")
    for key in sharedKeys:
        if first[key]==second[key]:
            print("Key: {}, Value 1: {}, Value 2: {}".format(key, first[key], second[key]))
            commun[key] = ("Value 1: {}, Value 2: {}".format(first[key], second[key]))
    print("-------------------------")
    print("Puis les clés identiques dont les valeurs ne sont pas identiques :")
    for key in sharedKeys:
        if first[key] != second[key]:
            print("Key: {}, Value 1: {}, Value 2: {}".format(key, first[key], second[key]))
    diffKeys = set(first.keys()).difference(second.keys())
    print("-------------------------")
    print("Puis tout ce qui est différent :")
    for key in diffKeys:
        if key in first : 
            print("Key 1: {}, Value 1 : {}".format(key, first[key]))
        if key in second:
            print("Key 2: {} , Value 2: {}".format(key, second[key]))
    write_json("corpusEntier_exactitudeTotale_CasENvsMano.json", commun)
    
    return (commun, len(commun))
    
compare(dicoCasEN, dicoMano)
# Out:
# D'abord, toutes les clés identiques avec valeurs identiques :
# Key: Ivan Netchiporko, Value 1: PER, Value 2: PER
# Key: Bordeaux, Value 1: LOC, Value 2: LOC
# Key: auteur, Value 1: FUNC, Value 2: FUNC
# Key: Rome, Value 1: LOC, Value 2: LOC
# Key: Conseil, Value 1: ORG, Value 2: ORG
# Key: Belgique, Value 1: LOC, Value 2: LOC
# Key: Andrew Wang, Value 1: PER, Value 2: PER
# Key: plus tôt, Value 1: TIME, Value 2: TIME
# Key: En 2006, Value 1: TIME, Value 2: TIME
# Key: Quelques mois, Value 1: AMOUNT, Value 2: AMOUNT
# Key: Donald Hadley, Value 1: PER, Value 2: PER
# Key: écrivains, Value 1: FUNC, Value 2: FUNC
# Key: Caen, Value 1: LOC, Value 2: LOC
# Key: 10 et 11 décembre, Value 1: TIME, Value 2: TIME
# Key: Cyclo Club Othéen, Value 1: ORG, Value 2: ORG
# Key: USA, Value 1: LOC, Value 2: LOC
# Key: Sylvie Vernageau, Value 1: PER, Value 2: PER
# Key: François Mitterrand, Value 1: PER, Value 2: PER
# Key: patineurs, Value 1: FUNC, Value 2: FUNC
# Key: en novembre de la même année, Value 1: TIME, Value 2: TIME
# Key: 23 juin au 7 juillet, Value 1: TIME, Value 2: TIME
# Key: vingt-quatre kilomètres, Value 1: AMOUNT, Value 2: AMOUNT
# Key: 150 €, Value 1: AMOUNT, Value 2: AMOUNT
# Key: dès septembre 2004, Value 1: TIME, Value 2: TIME
# Key: 9 mars 2018, Value 1: TIME, Value 2: TIME
# Key: vingt-sept kilomètres, Value 1: AMOUNT, Value 2: AMOUNT
# Key: René Bousquet, Value 1: PER, Value 2: PER
# Key: Banque d'Indochine, Value 1: ORG, Value 2: ORG
# Key: Joy Division, Value 1: PER, Value 2: PER
# Key: Boston, Value 1: LOC, Value 2: LOC
# Key: 48 heures, Value 1: AMOUNT, Value 2: AMOUNT
# Key: 15 €, Value 1: AMOUNT, Value 2: AMOUNT
# Key: Charasse, Value 1: PER, Value 2: PER
# Key: Jean Musy, Value 1: PER, Value 2: PER
# Key: Margaret Thatcher, Value 1: PER, Value 2: PER
# Key: le 20 mars 2018, Value 1: TIME, Value 2: TIME
# Key: Jiang Qing, Value 1: PER, Value 2: PER
# Key: Lisa, Value 1: PER, Value 2: PER
# Key: le 5 décembre, Value 1: TIME, Value 2: TIME
# Key: 23 juillet, Value 1: TIME, Value 2: TIME
# Key: météorologues, Value 1: FUNC, Value 2: FUNC
# Key: Blanche Maupas, Value 1: PER, Value 2: PER
# Key: Espagne, Value 1: LOC, Value 2: LOC
# Key: 3 €, Value 1: AMOUNT, Value 2: AMOUNT
# Key: 3 mars 2018, Value 1: TIME, Value 2: TIME
# Key: 2 semaines, Value 1: AMOUNT, Value 2: AMOUNT
# Key: dix-sept kilomètres, Value 1: AMOUNT, Value 2: AMOUNT
# Key: peintre, Value 1: FUNC, Value 2: FUNC
# Key: Aquitaine, Value 1: LOC, Value 2: LOC
# Key: quelques francs, Value 1: AMOUNT, Value 2: AMOUNT
# Key: Gabi Heinze, Value 1: PER, Value 2: PER
# Key: Saint-Eustache, Value 1: LOC, Value 2: LOC
# Key: Mao Zedong, Value 1: PER, Value 2: PER
# Key: en 2000, Value 1: TIME, Value 2: TIME
# Key: 15 septembre, Value 1: TIME, Value 2: TIME
# Key: Nations unies, Value 1: ORG, Value 2: ORG
# Key: Révolution française, Value 1: EVENT, Value 2: EVENT
# Key: à 20 h 30, Value 1: TIME, Value 2: TIME
# Key: Journées du Patrimoine, Value 1: EVENT, Value 2: EVENT
# Key: Parlement, Value 1: ORG, Value 2: ORG
# Key: au 2 décembre, Value 1: TIME, Value 2: TIME
# Key: Château de Guédelon, Value 1: LOC, Value 2: LOC
# Key: 20 janvier 1994, Value 1: TIME, Value 2: TIME
# Key: le soir, Value 1: TIME, Value 2: TIME
# Key: Pékin, Value 1: LOC, Value 2: LOC
# Key: professeurs, Value 1: FUNC, Value 2: FUNC
# Key: Royaume d'Egypte, Value 1: ORG, Value 2: ORG
# Key: île, Value 1: LOC, Value 2: LOC
# Key: Hollywood, Value 1: LOC, Value 2: LOC
# Key: de 14 h 30 à 18 h, Value 1: TIME, Value 2: TIME
# Key: juges belges, Value 1: FUNC, Value 2: FUNC
# Key: 5 ans, Value 1: AMOUNT, Value 2: AMOUNT
# Key: Taïwan, Value 1: LOC, Value 2: LOC
# Key: à partir de 7 h 30, Value 1: TIME, Value 2: TIME
# Key: Égypte, Value 1: LOC, Value 2: LOC
# Key: Angleterre, Value 1: LOC, Value 2: LOC
# Key: le 1er janvier 1811, Value 1: TIME, Value 2: TIME
# Key: en 1989, Value 1: TIME, Value 2: TIME
# Key: Bali, Value 1: LOC, Value 2: LOC
# Key: médecin, Value 1: FUNC, Value 2: FUNC
# Key: Thionville, Value 1: LOC, Value 2: LOC
# Key: Le soir, Value 1: TIME, Value 2: TIME
# Key: 4 mars 2018, Value 1: TIME, Value 2: TIME
# Key: procureur, Value 1: FUNC, Value 2: FUNC
# Key: En 1952, Value 1: TIME, Value 2: TIME
# Key: Inde, Value 1: LOC, Value 2: LOC
# Key: Musée Colette, Value 1: LOC, Value 2: LOC
# Key: Japon, Value 1: LOC, Value 2: LOC
# Key: États-Unis, Value 1: LOC, Value 2: LOC
# Key: Arabie, Value 1: LOC, Value 2: LOC
# Key: le 2 octobre 2006, Value 1: TIME, Value 2: TIME
# Key: quelques années, Value 1: AMOUNT, Value 2: AMOUNT
# Key: archevêque, Value 1: FUNC, Value 2: FUNC
# Key: de 10 h à 18 h, Value 1: TIME, Value 2: TIME
# Key: ancien Premier ministre, Value 1: FUNC, Value 2: FUNC
# Key: Antilles, Value 1: LOC, Value 2: LOC
# Key: quatre-vingt dix-neuf kilomètres, Value 1: AMOUNT, Value 2: AMOUNT
# Key: 500 euros, Value 1: AMOUNT, Value 2: AMOUNT
# Key: à 17 h, Value 1: TIME, Value 2: TIME
# Key: conducteur, Value 1: FUNC, Value 2: FUNC
# Key: vingt-six kilomètres, Value 1: AMOUNT, Value 2: AMOUNT
# Key: plusieurs décennies, Value 1: AMOUNT, Value 2: AMOUNT
# Key: le 2 novembre 2017, Value 1: TIME, Value 2: TIME
# Key: 26 ans, Value 1: AMOUNT, Value 2: AMOUNT
# Key: Saintes, Value 1: LOC, Value 2: LOC
# Key: En 1997, Value 1: TIME, Value 2: TIME
# Key: Narcisse Pigeon, Value 1: PER, Value 2: PER
# Key: dès le mois d'avril 1915, Value 1: TIME, Value 2: TIME
# Key: à ce moment, Value 1: TIME, Value 2: TIME
# Key: aujourd'hui, Value 1: TIME, Value 2: TIME
# Key: 5 €, Value 1: AMOUNT, Value 2: AMOUNT
# Key: portière, Value 1: FUNC, Value 2: FUNC
# Key: Oxford, Value 1: LOC, Value 2: LOC
# Key: Philippe Borecek, Value 1: PER, Value 2: PER
# Key: cent kilomètres, Value 1: AMOUNT, Value 2: AMOUNT
# Key: de 9 h 30 à 18 h, Value 1: TIME, Value 2: TIME
# Key: Suisse, Value 1: LOC, Value 2: LOC
# Key: Nigéria, Value 1: LOC, Value 2: LOC
# Key: le 6 septembre 1764, Value 1: TIME, Value 2: TIME
# Key: Francis Poullain, Value 1: PER, Value 2: PER
# Key: Lorient, Value 1: LOC, Value 2: LOC
# Key: Guangdong, Value 1: LOC, Value 2: LOC
# Key: en 1994, Value 1: TIME, Value 2: TIME
# Key: Jack London, Value 1: PER, Value 2: PER
# Key: La semaine dernière, Value 1: TIME, Value 2: TIME
# Key: 26 août, Value 1: TIME, Value 2: TIME
# Key: quarante-neuf kilomètres, Value 1: AMOUNT, Value 2: AMOUNT
# Key: Californie, Value 1: LOC, Value 2: LOC
# Key: trois minutes, Value 1: AMOUNT, Value 2: AMOUNT
# Key: Stanley Kubrick, Value 1: PER, Value 2: PER
# Key: James Webb, Value 1: PER, Value 2: PER
# Key: Afrique, Value 1: LOC, Value 2: LOC
# Key: Armstrong, Value 1: PER, Value 2: PER
# Key: Michael Faraday, Value 1: PER, Value 2: PER
# Key: Musée du Louvre, Value 1: LOC, Value 2: LOC
# Key: Front National, Value 1: ORG, Value 2: ORG
# Key: 8 mars 2018, Value 1: TIME, Value 2: TIME
# Key: plateau, Value 1: LOC, Value 2: LOC
# Key: Pacifique, Value 1: LOC, Value 2: LOC
# Key: Aube, Value 1: LOC, Value 2: LOC
# Key: Bourgogne, Value 1: LOC, Value 2: LOC
# Key: Octobre 2011, Value 1: TIME, Value 2: TIME
# Key: 22 ans, Value 1: AMOUNT, Value 2: AMOUNT
# Key: Europe, Value 1: LOC, Value 2: LOC
# Key: 16 juillet, Value 1: TIME, Value 2: TIME
# Key: 14 mars 2018, Value 1: TIME, Value 2: TIME
# Key: évêque, Value 1: FUNC, Value 2: FUNC
# Key: gendarmes, Value 1: FUNC, Value 2: FUNC
# Key: vingt-trois kilomètres, Value 1: AMOUNT, Value 2: AMOUNT
# Key: Object Management Group, Value 1: ORG, Value 2: ORG
# Key: Nicolas Collinet, Value 1: PER, Value 2: PER
# Key: Chine, Value 1: LOC, Value 2: LOC
# Key: vers quatre heures, Value 1: TIME, Value 2: TIME
# Key: Paul Vallier, Value 1: PER, Value 2: PER
# Key: 24 août, Value 1: TIME, Value 2: TIME
# Key: à 19 h, Value 1: TIME, Value 2: TIME
# Key: Michel Gondry, Value 1: PER, Value 2: PER
# Key: Dans la matinée, Value 1: TIME, Value 2: TIME
# Key: Aden, Value 1: LOC, Value 2: LOC
# Key: Le vendredi 2 mars 2018, Value 1: TIME, Value 2: TIME
# Key: auteurs, Value 1: FUNC, Value 2: FUNC
# Key: Maroc, Value 1: LOC, Value 2: LOC
# Key: Cambridge, Value 1: LOC, Value 2: LOC
# Key: Kafka, Value 1: PER, Value 2: PER
# Key: NASA, Value 1: ORG, Value 2: ORG
# Key: auparavant, Value 1: TIME, Value 2: TIME
# Key: Nicolas Sarkozy, Value 1: PER, Value 2: PER
# Key: Paul Breisch, Value 1: PER, Value 2: PER
# Key: Ouagadougou, Value 1: LOC, Value 2: LOC
# Key: deux cent quatre-vingt huit kilomètres, Value 1: AMOUNT, Value 2: AMOUNT
# Key: tous les jours, Value 1: TIME, Value 2: TIME
# Key: À cette heure avancée de la nuit, Value 1: TIME, Value 2: TIME
# Key: quatre-vingt onze kilomètres, Value 1: AMOUNT, Value 2: AMOUNT
# Key: Musée du Cidre, Value 1: LOC, Value 2: LOC
# Key: Hyères, Value 1: LOC, Value 2: LOC
# Key: à partir de 1950, Value 1: TIME, Value 2: TIME
# Key: 20 novembre, Value 1: TIME, Value 2: TIME
# Key: ces 25 dernières années, Value 1: TIME, Value 2: TIME
# Key: conceptrice, Value 1: FUNC, Value 2: FUNC
# Key: marchand, Value 1: FUNC, Value 2: FUNC
# Key: Saint-Lô, Value 1: LOC, Value 2: LOC
# Key: Carthagène, Value 1: LOC, Value 2: LOC
# Key: le 11 avril 1814, Value 1: TIME, Value 2: TIME
# Key: cette soirée, Value 1: TIME, Value 2: TIME
# Key: 10 mars 2018, Value 1: TIME, Value 2: TIME
# Key: ministre socialiste du Budget, Value 1: FUNC, Value 2: FUNC
# Key: Meuse, Value 1: LOC, Value 2: LOC
# Key: maintenant, Value 1: TIME, Value 2: TIME
# Key: lutteur, Value 1: FUNC, Value 2: FUNC
# Key: 28 mai 2004, Value 1: TIME, Value 2: TIME
# Key: ces derniers jours, Value 1: TIME, Value 2: TIME
# Key: Juillet 2011, Value 1: TIME, Value 2: TIME
# Key: Renoir, Value 1: PER, Value 2: PER
# Key: Créteil, Value 1: LOC, Value 2: LOC
# Key: 723 premières années, Value 1: AMOUNT, Value 2: AMOUNT
# Key: Bob Hope, Value 1: PER, Value 2: PER
# Key: Oslo, Value 1: LOC, Value 2: LOC
# Key: Diderot, Value 1: PER, Value 2: PER
# Key: scientifiques, Value 1: FUNC, Value 2: FUNC
# Key: cinq minutes, Value 1: AMOUNT, Value 2: AMOUNT
# Key: en 1996, Value 1: TIME, Value 2: TIME
# Key: du 3 mars, Value 1: TIME, Value 2: TIME
# Key: Le 17 mai 2004, Value 1: TIME, Value 2: TIME
# Key: en 1933, Value 1: TIME, Value 2: TIME
# Key: vers vingt heures, Value 1: TIME, Value 2: TIME
# Key: laboratoires, Value 1: ORG, Value 2: ORG
# Key: Olav Tryggvason, Value 1: PER, Value 2: PER
# Key: en 2011, Value 1: TIME, Value 2: TIME
# Key: 18 ans, Value 1: AMOUNT, Value 2: AMOUNT
# Key: John Foxx, Value 1: PER, Value 2: PER
# Key: océan, Value 1: LOC, Value 2: LOC
# Key: Hugues Mingarelli, Value 1: PER, Value 2: PER
# Key: Russie, Value 1: LOC, Value 2: LOC
# Key: Carcassonne, Value 1: LOC, Value 2: LOC
# Key: pilote, Value 1: FUNC, Value 2: FUNC
# Key: Somalie, Value 1: LOC, Value 2: LOC
# Key: Halle Circulaire, Value 1: LOC, Value 2: LOC
# Key: Sept ans, Value 1: AMOUNT, Value 2: AMOUNT
# Key: îles, Value 1: LOC, Value 2: LOC
# Key: Pierre-Antoine Demachy, Value 1: PER, Value 2: PER
# Key: le vingt-et-unième siècle, Value 1: TIME, Value 2: TIME
# Key: MAROLLES-SOUS-LIGNIERES, Value 1: LOC, Value 2: LOC
# Key: Fête du Cochon, Value 1: EVENT, Value 2: EVENT
# Key: En 1998, Value 1: TIME, Value 2: TIME
# Key: Matthieu Normand, Value 1: PER, Value 2: PER
# Key: United Service Organizations, Value 1: ORG, Value 2: ORG
# Key: entre 12 h et 14 h, Value 1: TIME, Value 2: TIME
# Key: Cherbourg-Octeville, Value 1: LOC, Value 2: LOC
# Key: patron, Value 1: FUNC, Value 2: FUNC
# Key: en 1922, Value 1: TIME, Value 2: TIME
# Key: Théophile Maupas, Value 1: PER, Value 2: PER
# Key: France, Value 1: LOC, Value 2: LOC
# Key: l'après-midi, Value 1: TIME, Value 2: TIME
# Key: église, Value 1: LOC, Value 2: LOC
# Key: Fukushima, Value 1: LOC, Value 2: LOC
# Key: cinquante francs, Value 1: AMOUNT, Value 2: AMOUNT
# Key: LVMH, Value 1: ORG, Value 2: ORG
# Key: CRS, Value 1: FUNC, Value 2: FUNC
# Key: Michel Charasse, Value 1: PER, Value 2: PER
# Key: Mont, Value 1: LOC, Value 2: LOC
# Key: Canton, Value 1: LOC, Value 2: LOC
# Key: Royaume-Uni, Value 1: LOC, Value 2: LOC
# Key: Palaiseau, Value 1: LOC, Value 2: LOC
# Key: Groenland, Value 1: LOC, Value 2: LOC
# Key: justice espagnole, Value 1: ORG, Value 2: ORG
# Key: boulanger, Value 1: FUNC, Value 2: FUNC
# Key: Balthazar, Value 1: PER, Value 2: PER
# Key: Terre, Value 1: LOC, Value 2: LOC
# Key: 11 mars 2018, Value 1: TIME, Value 2: TIME
# Key: de 1930 à 1942, Value 1: TIME, Value 2: TIME
# Key: le mois précédent, Value 1: TIME, Value 2: TIME
# Key: rivière des Perles, Value 1: LOC, Value 2: LOC
# Key: Jeux olympiques, Value 1: EVENT, Value 2: EVENT
# Key: Paris, Value 1: LOC, Value 2: LOC
# Key: New York, Value 1: LOC, Value 2: LOC
# Key: 250 années, Value 1: AMOUNT, Value 2: AMOUNT
# Key: Ethiopie, Value 1: LOC, Value 2: LOC
# Key: Cameroun, Value 1: LOC, Value 2: LOC
# Key: 8 septembre, Value 1: TIME, Value 2: TIME
# Key: 355 €, Value 1: AMOUNT, Value 2: AMOUNT
# Key: Aujourd'hui, Value 1: TIME, Value 2: TIME
# Key: pour cette nouvelle année, Value 1: TIME, Value 2: TIME
# Key: joueurs, Value 1: FUNC, Value 2: FUNC
# Key: monts Oural, Value 1: LOC, Value 2: LOC
# Key: forêt, Value 1: LOC, Value 2: LOC
# Key: 4 septembre, Value 1: TIME, Value 2: TIME
# Key: délégués syndicaux, Value 1: FUNC, Value 2: FUNC
# Key: en 1962, Value 1: TIME, Value 2: TIME
# Key: quatre minutes, Value 1: AMOUNT, Value 2: AMOUNT
# Key: bientôt, Value 1: TIME, Value 2: TIME
# Key: avant vingt heures quinze, Value 1: TIME, Value 2: TIME
# -------------------------
# Puis les clés identiques dont les valeurs ne sont pas identiques :
# Key: El Niño, Value 1: PER, Value 2: LOC
# Key: The Normal, Value 1: ORG, Value 2: PER
# Key: Bolloré, Value 1: ORG, Value 2: PER
# Key: UE, Value 1: LOC, Value 2: ORG
# Key: Actium, Value 1: EVENT, Value 2: LOC
# Key: Louis Vuitton, Value 1: PER, Value 2: ORG
# Key: Villa de l'Extra, Value 1: LOC, Value 2: ORG
# Key: Metallica, Value 1: ORG, Value 2: PER
# Key: Notre-Dame, Value 1: PER, Value 2: LOC
# Key: Galilée, Value 1: LOC, Value 2: PER
# Key: Saturne, Value 1: PER, Value 2: LOC
# Key: Hong Kong, Value 1: PER, Value 2: LOC
# Key: SoHO, Value 1: LOC, Value 2: PROD
# Key: dix-neuf heures trente, Value 1: AMOUNT, Value 2: TIME
# -------------------------
# Puis tout ce qui est différent :
# Key 1: lycée, Value 1 : ORG
# Key 1: foreuse, Value 1 : FUNC
# Key 1: boutique, Value 1 : ORG
# Key 1: élevage, Value 1 : ORG
# Key 1: université, Value 1 : ORG
# Key 1: père, Value 1 : FUNC
# Key 1: Michel, Value 1 : PER
# Key 1: le jour, Value 1 : TIME
# Key 1: général, Value 1 : FUNC
# Key 1: des saisons, Value 1 : AMOUNT
# Key 1: département du, Value 1 : LOC
# Key 1: équipe, Value 1 : ORG
# Key 1: chaque année, Value 1 : TIME
# Key 1: jardins, Value 1 : ORG
# Key 1: jardin, Value 1 : ORG
# Key 1: entreprise, Value 1 : ORG
# Key 1: Une soirée, Value 1 : AMOUNT
# Key 1: marines, Value 1 : ORG
# Key 1: presse, Value 1 : ORG
# Key 1: documentaires, Value 1 : PROD
# Key 1: un instant, Value 1 : AMOUNT
# Key 1: les trente derniers, Value 1 : TIME
# Key 1: un livre, Value 1 : AMOUNT
# Key 1: école, Value 1 : ORG
# Key 1: entreprises, Value 1 : ORG
# Key 1: Collégiale Royale, Value 1 : LOC
# Key 1: pour ce moment, Value 1 : TIME
# Key 1: premiers livres, Value 1 : AMOUNT
# Key 1: surface, Value 1 : LOC
# Key 1: Juif, Value 1 : PER
# Key 1: capitale du, Value 1 : LOC
# Key 1: sommet, Value 1 : LOC
# Key 1: Cabaret, Value 1 : ORG
# Key 1: Division, Value 1 : PER
# Key 1: magazine, Value 1 : PROD
# Key 1: la journée, Value 1 : TIME
# Key 1: 2ème jour, Value 1 : AMOUNT
# Key 1: Saint-Jean, Value 1 : LOC
# Key 1: école primaire, Value 1 : ORG
# Key 1: Pays, Value 1 : ORG
# Key 1: ville de, Value 1 : LOC
# Key 1: le siècle, Value 1 : TIME
# Key 1: des soirées, Value 1 : AMOUNT
# Key 1: plaine, Value 1 : LOC
# Key 1: chefs, Value 1 : FUNC
# Key 1: mondial, Value 1 : EVENT
# Key 1: Maurienne, Value 1 : LOC
# Key 1: à, Value 1 : TIME
# Key 1: chef, Value 1 : FUNC
# Key 1: armées, Value 1 : ORG
# Key 1: voyageur, Value 1 : FUNC
# Key 1: null, Value 1 : PER
# Key 1: Chroniques, Value 1 : PROD
# Key 1: juges, Value 1 : FUNC
# Key 1: les journées, Value 1 : TIME
# Key 1: Café, Value 1 : ORG
# Key 1: département français des, Value 1 : ORG
# Key 1: pour l' instant, Value 1 : TIME
# Key 1: chaque mois, Value 1 : TIME
# Key 1: département de la, Value 1 : LOC
# Key 1: 5S, Value 1 : AMOUNT
# Key 1: consortium, Value 1 : ORG
# Key 1: Une seconde, Value 1 : AMOUNT
# Key 1: mère, Value 1 : FUNC
# Key 1: tout an, Value 1 : TIME
# Key 1: avril, Value 1 : TIME
# ({'Ivan Netchiporko': 'Value 1: PER, Value 2: PER',
#   'Bordeaux': 'Value 1: LOC, Value 2: LOC',
#   'auteur': 'Value 1: FUNC, Value 2: FUNC',
#   'Rome': 'Value 1: LOC, Value 2: LOC',
#   'Conseil': 'Value 1: ORG, Value 2: ORG',
#   'Belgique': 'Value 1: LOC, Value 2: LOC',
#   'Andrew Wang': 'Value 1: PER, Value 2: PER',
#   'plus tôt': 'Value 1: TIME, Value 2: TIME',
#   'En 2006': 'Value 1: TIME, Value 2: TIME',
#   'Quelques mois': 'Value 1: AMOUNT, Value 2: AMOUNT',
#   'Donald Hadley': 'Value 1: PER, Value 2: PER',
#   'écrivains': 'Value 1: FUNC, Value 2: FUNC',
#   'Caen': 'Value 1: LOC, Value 2: LOC',
#   '10 et 11 décembre': 'Value 1: TIME, Value 2: TIME',
#   'Cyclo Club Othéen': 'Value 1: ORG, Value 2: ORG',
#   'USA': 'Value 1: LOC, Value 2: LOC',
#   'Sylvie Vernageau': 'Value 1: PER, Value 2: PER',
#   'François Mitterrand': 'Value 1: PER, Value 2: PER',
#   'patineurs': 'Value 1: FUNC, Value 2: FUNC',
#   'en novembre de la même année': 'Value 1: TIME, Value 2: TIME',
#   '23 juin au 7 juillet': 'Value 1: TIME, Value 2: TIME',
#   'vingt-quatre kilomètres': 'Value 1: AMOUNT, Value 2: AMOUNT',
#   '150 €': 'Value 1: AMOUNT, Value 2: AMOUNT',
#   'dès septembre 2004': 'Value 1: TIME, Value 2: TIME',
#   '9 mars 2018': 'Value 1: TIME, Value 2: TIME',
#   'vingt-sept kilomètres': 'Value 1: AMOUNT, Value 2: AMOUNT',
#   'René Bousquet': 'Value 1: PER, Value 2: PER',
#   "Banque d'Indochine": 'Value 1: ORG, Value 2: ORG',
#   'Joy Division': 'Value 1: PER, Value 2: PER',
#   'Boston': 'Value 1: LOC, Value 2: LOC',
#   '48 heures': 'Value 1: AMOUNT, Value 2: AMOUNT',
#   '15 €': 'Value 1: AMOUNT, Value 2: AMOUNT',
#   'Charasse': 'Value 1: PER, Value 2: PER',
#   'Jean Musy': 'Value 1: PER, Value 2: PER',
#   'Margaret Thatcher': 'Value 1: PER, Value 2: PER',
#   'le 20 mars 2018': 'Value 1: TIME, Value 2: TIME',
#   'Jiang Qing': 'Value 1: PER, Value 2: PER',
#   'Lisa': 'Value 1: PER, Value 2: PER',
#   'le 5 décembre': 'Value 1: TIME, Value 2: TIME',
#   '23 juillet': 'Value 1: TIME, Value 2: TIME',
#   'météorologues': 'Value 1: FUNC, Value 2: FUNC',
#   'Blanche Maupas': 'Value 1: PER, Value 2: PER',
#   'Espagne': 'Value 1: LOC, Value 2: LOC',
#   '3 €': 'Value 1: AMOUNT, Value 2: AMOUNT',
#   '3 mars 2018': 'Value 1: TIME, Value 2: TIME',
#   '2 semaines': 'Value 1: AMOUNT, Value 2: AMOUNT',
#   'dix-sept kilomètres': 'Value 1: AMOUNT, Value 2: AMOUNT',
#   'peintre': 'Value 1: FUNC, Value 2: FUNC',
#   'Aquitaine': 'Value 1: LOC, Value 2: LOC',
#   'quelques francs': 'Value 1: AMOUNT, Value 2: AMOUNT',
#   'Gabi Heinze': 'Value 1: PER, Value 2: PER',
#   'Saint-Eustache': 'Value 1: LOC, Value 2: LOC',
#   'Mao Zedong': 'Value 1: PER, Value 2: PER',
#   'en 2000': 'Value 1: TIME, Value 2: TIME',
#   '15 septembre': 'Value 1: TIME, Value 2: TIME',
#   'Nations unies': 'Value 1: ORG, Value 2: ORG',
#   'Révolution française': 'Value 1: EVENT, Value 2: EVENT',
#   'à 20 h 30': 'Value 1: TIME, Value 2: TIME',
#   'Journées du Patrimoine': 'Value 1: EVENT, Value 2: EVENT',
#   'Parlement': 'Value 1: ORG, Value 2: ORG',
#   'au 2 décembre': 'Value 1: TIME, Value 2: TIME',
#   'Château de Guédelon': 'Value 1: LOC, Value 2: LOC',
#   '20 janvier 1994': 'Value 1: TIME, Value 2: TIME',
#   'le soir': 'Value 1: TIME, Value 2: TIME',
#   'Pékin': 'Value 1: LOC, Value 2: LOC',
#   'professeurs': 'Value 1: FUNC, Value 2: FUNC',
#   "Royaume d'Egypte": 'Value 1: ORG, Value 2: ORG',
#   'île': 'Value 1: LOC, Value 2: LOC',
#   'Hollywood': 'Value 1: LOC, Value 2: LOC',
#   'de 14 h 30 à 18 h': 'Value 1: TIME, Value 2: TIME',
#   'juges belges': 'Value 1: FUNC, Value 2: FUNC',
#   '5 ans': 'Value 1: AMOUNT, Value 2: AMOUNT',
#   'Taïwan': 'Value 1: LOC, Value 2: LOC',
#   'à partir de 7 h 30': 'Value 1: TIME, Value 2: TIME',
#   'Égypte': 'Value 1: LOC, Value 2: LOC',
#   'Angleterre': 'Value 1: LOC, Value 2: LOC',
#   'le 1er janvier 1811': 'Value 1: TIME, Value 2: TIME',
#   'en 1989': 'Value 1: TIME, Value 2: TIME',
#   'Bali': 'Value 1: LOC, Value 2: LOC',
#   'médecin': 'Value 1: FUNC, Value 2: FUNC',
#   'Thionville': 'Value 1: LOC, Value 2: LOC',
#   'Le soir': 'Value 1: TIME, Value 2: TIME',
#   '4 mars 2018': 'Value 1: TIME, Value 2: TIME',
#   'procureur': 'Value 1: FUNC, Value 2: FUNC',
#   'En 1952': 'Value 1: TIME, Value 2: TIME',
#   'Inde': 'Value 1: LOC, Value 2: LOC',
#   'Musée Colette': 'Value 1: LOC, Value 2: LOC',
#   'Japon': 'Value 1: LOC, Value 2: LOC',
#   'États-Unis': 'Value 1: LOC, Value 2: LOC',
#   'Arabie': 'Value 1: LOC, Value 2: LOC',
#   'le 2 octobre 2006': 'Value 1: TIME, Value 2: TIME',
#   'quelques années': 'Value 1: AMOUNT, Value 2: AMOUNT',
#   'archevêque': 'Value 1: FUNC, Value 2: FUNC',
#   'de 10 h à 18 h': 'Value 1: TIME, Value 2: TIME',
#   'ancien Premier ministre': 'Value 1: FUNC, Value 2: FUNC',
#   'Antilles': 'Value 1: LOC, Value 2: LOC',
#   'quatre-vingt dix-neuf kilomètres': 'Value 1: AMOUNT, Value 2: AMOUNT',
#   '500 euros': 'Value 1: AMOUNT, Value 2: AMOUNT',
#   'à 17 h': 'Value 1: TIME, Value 2: TIME',
#   'conducteur': 'Value 1: FUNC, Value 2: FUNC',
#   'vingt-six kilomètres': 'Value 1: AMOUNT, Value 2: AMOUNT',
#   'plusieurs décennies': 'Value 1: AMOUNT, Value 2: AMOUNT',
#   'le 2 novembre 2017': 'Value 1: TIME, Value 2: TIME',
#   '26 ans': 'Value 1: AMOUNT, Value 2: AMOUNT',
#   'Saintes': 'Value 1: LOC, Value 2: LOC',
#   'En 1997': 'Value 1: TIME, Value 2: TIME',
#   'Narcisse Pigeon': 'Value 1: PER, Value 2: PER',
#   "dès le mois d'avril 1915": 'Value 1: TIME, Value 2: TIME',
#   'à ce moment': 'Value 1: TIME, Value 2: TIME',
#   "aujourd'hui": 'Value 1: TIME, Value 2: TIME',
#   '5 €': 'Value 1: AMOUNT, Value 2: AMOUNT',
#   'portière': 'Value 1: FUNC, Value 2: FUNC',
#   'Oxford': 'Value 1: LOC, Value 2: LOC',
#   'Philippe Borecek': 'Value 1: PER, Value 2: PER',
#   'cent kilomètres': 'Value 1: AMOUNT, Value 2: AMOUNT',
#   'de 9 h 30 à 18 h': 'Value 1: TIME, Value 2: TIME',
#   'Suisse': 'Value 1: LOC, Value 2: LOC',
#   'Nigéria': 'Value 1: LOC, Value 2: LOC',
#   'le 6 septembre 1764': 'Value 1: TIME, Value 2: TIME',
#   'Francis Poullain': 'Value 1: PER, Value 2: PER',
#   'Lorient': 'Value 1: LOC, Value 2: LOC',
#   'Guangdong': 'Value 1: LOC, Value 2: LOC',
#   'en 1994': 'Value 1: TIME, Value 2: TIME',
#   'Jack London': 'Value 1: PER, Value 2: PER',
#   'La semaine dernière': 'Value 1: TIME, Value 2: TIME',
#   '26 août': 'Value 1: TIME, Value 2: TIME',
#   'quarante-neuf kilomètres': 'Value 1: AMOUNT, Value 2: AMOUNT',
#   'Californie': 'Value 1: LOC, Value 2: LOC',
#   'trois minutes': 'Value 1: AMOUNT, Value 2: AMOUNT',
#   'Stanley Kubrick': 'Value 1: PER, Value 2: PER',
#   'James Webb': 'Value 1: PER, Value 2: PER',
#   'Afrique': 'Value 1: LOC, Value 2: LOC',
#   'Armstrong': 'Value 1: PER, Value 2: PER',
#   'Michael Faraday': 'Value 1: PER, Value 2: PER',
#   'Musée du Louvre': 'Value 1: LOC, Value 2: LOC',
#   'Front National': 'Value 1: ORG, Value 2: ORG',
#   '8 mars 2018': 'Value 1: TIME, Value 2: TIME',
#   'plateau': 'Value 1: LOC, Value 2: LOC',
#   'Pacifique': 'Value 1: LOC, Value 2: LOC',
#   'Aube': 'Value 1: LOC, Value 2: LOC',
#   'Bourgogne': 'Value 1: LOC, Value 2: LOC',
#   'Octobre 2011': 'Value 1: TIME, Value 2: TIME',
#   '22 ans': 'Value 1: AMOUNT, Value 2: AMOUNT',
#   'Europe': 'Value 1: LOC, Value 2: LOC',
#   '16 juillet': 'Value 1: TIME, Value 2: TIME',
#   '14 mars 2018': 'Value 1: TIME, Value 2: TIME',
#   'évêque': 'Value 1: FUNC, Value 2: FUNC',
#   'gendarmes': 'Value 1: FUNC, Value 2: FUNC',
#   'vingt-trois kilomètres': 'Value 1: AMOUNT, Value 2: AMOUNT',
#   'Object Management Group': 'Value 1: ORG, Value 2: ORG',
#   'Nicolas Collinet': 'Value 1: PER, Value 2: PER',
#   'Chine': 'Value 1: LOC, Value 2: LOC',
#   'vers quatre heures': 'Value 1: TIME, Value 2: TIME',
#   'Paul Vallier': 'Value 1: PER, Value 2: PER',
#   '24 août': 'Value 1: TIME, Value 2: TIME',
#   'à 19 h': 'Value 1: TIME, Value 2: TIME',
#   'Michel Gondry': 'Value 1: PER, Value 2: PER',
#   'Dans la matinée': 'Value 1: TIME, Value 2: TIME',
#   'Aden': 'Value 1: LOC, Value 2: LOC',
#   'Le vendredi 2 mars 2018': 'Value 1: TIME, Value 2: TIME',
#   'auteurs': 'Value 1: FUNC, Value 2: FUNC',
#   'Maroc': 'Value 1: LOC, Value 2: LOC',
#   'Cambridge': 'Value 1: LOC, Value 2: LOC',
#   'Kafka': 'Value 1: PER, Value 2: PER',
#   'NASA': 'Value 1: ORG, Value 2: ORG',
#   'auparavant': 'Value 1: TIME, Value 2: TIME',
#   'Nicolas Sarkozy': 'Value 1: PER, Value 2: PER',
#   'Paul Breisch': 'Value 1: PER, Value 2: PER',
#   'Ouagadougou': 'Value 1: LOC, Value 2: LOC',
#   'deux cent quatre-vingt huit kilomètres': 'Value 1: AMOUNT, Value 2: AMOUNT',
#   'tous les jours': 'Value 1: TIME, Value 2: TIME',
#   'À cette heure avancée de la nuit': 'Value 1: TIME, Value 2: TIME',
#   'quatre-vingt onze kilomètres': 'Value 1: AMOUNT, Value 2: AMOUNT',
#   'Musée du Cidre': 'Value 1: LOC, Value 2: LOC',
#   'Hyères': 'Value 1: LOC, Value 2: LOC',
#   'à partir de 1950': 'Value 1: TIME, Value 2: TIME',
#   '20 novembre': 'Value 1: TIME, Value 2: TIME',
#   'ces 25 dernières années': 'Value 1: TIME, Value 2: TIME',
#   'conceptrice': 'Value 1: FUNC, Value 2: FUNC',
#   'marchand': 'Value 1: FUNC, Value 2: FUNC',
#   'Saint-Lô': 'Value 1: LOC, Value 2: LOC',
#   'Carthagène': 'Value 1: LOC, Value 2: LOC',
#   'le 11 avril 1814': 'Value 1: TIME, Value 2: TIME',
#   'cette soirée': 'Value 1: TIME, Value 2: TIME',
#   '10 mars 2018': 'Value 1: TIME, Value 2: TIME',
#   'ministre socialiste du Budget': 'Value 1: FUNC, Value 2: FUNC',
#   'Meuse': 'Value 1: LOC, Value 2: LOC',
#   'maintenant': 'Value 1: TIME, Value 2: TIME',
#   'lutteur': 'Value 1: FUNC, Value 2: FUNC',
#   '28 mai 2004': 'Value 1: TIME, Value 2: TIME',
#   'ces derniers jours': 'Value 1: TIME, Value 2: TIME',
#   'Juillet 2011': 'Value 1: TIME, Value 2: TIME',
#   'Renoir': 'Value 1: PER, Value 2: PER',
#   'Créteil': 'Value 1: LOC, Value 2: LOC',
#   '723 premières années': 'Value 1: AMOUNT, Value 2: AMOUNT',
#   'Bob Hope': 'Value 1: PER, Value 2: PER',
#   'Oslo': 'Value 1: LOC, Value 2: LOC',
#   'Diderot': 'Value 1: PER, Value 2: PER',
#   'scientifiques': 'Value 1: FUNC, Value 2: FUNC',
#   'cinq minutes': 'Value 1: AMOUNT, Value 2: AMOUNT',
#   'en 1996': 'Value 1: TIME, Value 2: TIME',
#   'du 3 mars': 'Value 1: TIME, Value 2: TIME',
#   'Le 17 mai 2004': 'Value 1: TIME, Value 2: TIME',
#   'en 1933': 'Value 1: TIME, Value 2: TIME',
#   'vers vingt heures': 'Value 1: TIME, Value 2: TIME',
#   'laboratoires': 'Value 1: ORG, Value 2: ORG',
#   'Olav Tryggvason': 'Value 1: PER, Value 2: PER',
#   'en 2011': 'Value 1: TIME, Value 2: TIME',
#   '18 ans': 'Value 1: AMOUNT, Value 2: AMOUNT',
#   'John Foxx': 'Value 1: PER, Value 2: PER',
#   'océan': 'Value 1: LOC, Value 2: LOC',
#   'Hugues Mingarelli': 'Value 1: PER, Value 2: PER',
#   'Russie': 'Value 1: LOC, Value 2: LOC',
#   'Carcassonne': 'Value 1: LOC, Value 2: LOC',
#   'pilote': 'Value 1: FUNC, Value 2: FUNC',
#   'Somalie': 'Value 1: LOC, Value 2: LOC',
#   'Halle Circulaire': 'Value 1: LOC, Value 2: LOC',
#   'Sept ans': 'Value 1: AMOUNT, Value 2: AMOUNT',
#   'îles': 'Value 1: LOC, Value 2: LOC',
#   'Pierre-Antoine Demachy': 'Value 1: PER, Value 2: PER',
#   'le vingt-et-unième siècle': 'Value 1: TIME, Value 2: TIME',
#   'MAROLLES-SOUS-LIGNIERES': 'Value 1: LOC, Value 2: LOC',
#   'Fête du Cochon': 'Value 1: EVENT, Value 2: EVENT',
#   'En 1998': 'Value 1: TIME, Value 2: TIME',
#   'Matthieu Normand': 'Value 1: PER, Value 2: PER',
#   'United Service Organizations': 'Value 1: ORG, Value 2: ORG',
#   'entre 12 h et 14 h': 'Value 1: TIME, Value 2: TIME',
#   'Cherbourg-Octeville': 'Value 1: LOC, Value 2: LOC',
#   'patron': 'Value 1: FUNC, Value 2: FUNC',
#   'en 1922': 'Value 1: TIME, Value 2: TIME',
#   'Théophile Maupas': 'Value 1: PER, Value 2: PER',
#   'France': 'Value 1: LOC, Value 2: LOC',
#   "l'après-midi": 'Value 1: TIME, Value 2: TIME',
#   'église': 'Value 1: LOC, Value 2: LOC',
#   'Fukushima': 'Value 1: LOC, Value 2: LOC',
#   'cinquante francs': 'Value 1: AMOUNT, Value 2: AMOUNT',
#   'LVMH': 'Value 1: ORG, Value 2: ORG',
#   'CRS': 'Value 1: FUNC, Value 2: FUNC',
#   'Michel Charasse': 'Value 1: PER, Value 2: PER',
#   'Mont': 'Value 1: LOC, Value 2: LOC',
#   'Canton': 'Value 1: LOC, Value 2: LOC',
#   'Royaume-Uni': 'Value 1: LOC, Value 2: LOC',
#   'Palaiseau': 'Value 1: LOC, Value 2: LOC',
#   'Groenland': 'Value 1: LOC, Value 2: LOC',
#   'justice espagnole': 'Value 1: ORG, Value 2: ORG',
#   'boulanger': 'Value 1: FUNC, Value 2: FUNC',
#   'Balthazar': 'Value 1: PER, Value 2: PER',
#   'Terre': 'Value 1: LOC, Value 2: LOC',
#   '11 mars 2018': 'Value 1: TIME, Value 2: TIME',
#   'de 1930 à 1942': 'Value 1: TIME, Value 2: TIME',
#   'le mois précédent': 'Value 1: TIME, Value 2: TIME',
#   'rivière des Perles': 'Value 1: LOC, Value 2: LOC',
#   'Jeux olympiques': 'Value 1: EVENT, Value 2: EVENT',
#   'Paris': 'Value 1: LOC, Value 2: LOC',
#   'New York': 'Value 1: LOC, Value 2: LOC',
#   '250 années': 'Value 1: AMOUNT, Value 2: AMOUNT',
#   'Ethiopie': 'Value 1: LOC, Value 2: LOC',
#   'Cameroun': 'Value 1: LOC, Value 2: LOC',
#   '8 septembre': 'Value 1: TIME, Value 2: TIME',
#   '355 €': 'Value 1: AMOUNT, Value 2: AMOUNT',
#   "Aujourd'hui": 'Value 1: TIME, Value 2: TIME',
#   'pour cette nouvelle année': 'Value 1: TIME, Value 2: TIME',
#   'joueurs': 'Value 1: FUNC, Value 2: FUNC',
#   'monts Oural': 'Value 1: LOC, Value 2: LOC',
#   'forêt': 'Value 1: LOC, Value 2: LOC',
#   '4 septembre': 'Value 1: TIME, Value 2: TIME',
#   'délégués syndicaux': 'Value 1: FUNC, Value 2: FUNC',
#   'en 1962': 'Value 1: TIME, Value 2: TIME',
#   'quatre minutes': 'Value 1: AMOUNT, Value 2: AMOUNT',
#   'bientôt': 'Value 1: TIME, Value 2: TIME',
#   'avant vingt heures quinze': 'Value 1: TIME, Value 2: TIME'},
#  271)

# %% [markdown]
# ### Calculs

# %%
lenCasEN = len(dicoCasEN)
print(lenCasEN)
# Out:
# 351

# %%
lenMano = len(dicoMano)
print(lenMano)
# Out:
# 637

# %%
ensemble = len(dicoCasEN)+len(dicoMano)
print(ensemble)
# Out:
# 988

# %%
commun = 271

# %%
precision = commun / lenCasEN
print(precision)
# Out:
# 0.7720797720797721

# %%
rappel = commun / lenMano
print(rappel)
# Out:
# 0.42543171114599687

# %%
f1 = 2*precision*rappel/(precision+rappel)
print(f1)
# Out:
# 0.548582995951417

# %% [markdown]
# ## Exactitude partielle

# %% [markdown]
# ### Visualisation

# %%
#on créé un dico des annotations CasEN
dicoCasEN = {}
for i in liste_fic:
    path_fic = folder1+i+ext1
    fic = ouvrir_json(path_fic)
    for j in fic:
        dicoCasEN[j.strip()]=(fic[j]).strip()

#print(dicoCasEN)

dicoMano = {}
for i in liste_fic:
    path_fic2 = folder2+i+ext2
    fic2 = ouvrir_json(path_fic2)
    for j in fic2:
        dicoMano[j.strip()]=(fic2[j]).strip()

#print(dicoMano)

sorted(dicoCasEN.items(), key=lambda t: t[0])

sorted(dicoMano.items(), key=lambda t: t[0])

def compare(first, second):
    commun = {}
    sharedKeys = set(first.keys()).intersection(second.keys())
    print("D'abord, toutes les clés identiques avec valeurs identiques : ")
    for key in sharedKeys:
        if first[key]==second[key]:
            #print("Key: {}, Value 1: {}, Value 2: {}".format(key, first[key], second[key]))
            commun[key] = ("Value 1: {}, Value 2: {}".format(first[key], second[key]))
    print("-------------------------")
    print("Puis les clés identiques dont les valeurs ne sont pas identiques :")
    for key in sharedKeys:
        if first[key] != second[key]:
            #print("Key: {}, Value 1: {}, Value 2: {}".format(key, first[key], second[key]))
            commun[key] = ("Value 1: {}, Value 2: {}".format(first[key], second[key]))
    diffKeys = set(first.keys()).difference(second.keys())
    print("-------------------------")
    print("Puis tout ce qui est différent :")
    #for key in diffKeys:
        #if key in first : 
            #print("Key 1: {}, Value 1 : {}".format(key, first[key]))
        #if key in second:
            #print("Key 2: {} , Value 2: {}".format(key, second[key]))
    write_json("corpusEntier_exactitudePartielle_CasENvsMano.json", commun)
    
    return (len(commun))
    
compare(dicoCasEN, dicoMano)
# Out:
# D'abord, toutes les clés identiques avec valeurs identiques :
# -------------------------
# Puis les clés identiques dont les valeurs ne sont pas identiques :
# -------------------------
# Puis tout ce qui est différent :
# 285

# %% [markdown]
# ### Calculs

# %%
lenCasEN = len(dicoCasEN)
print(lenCasEN)

lenMano = len(dicoMano)
print(lenMano)

ensemble = len(dicoCasEN)+len(dicoMano)
print(ensemble)

commun = 285

precision = commun / lenCasEN
print(precision)

rappel = commun / lenMano
print(rappel)

f1 = 2*precision*rappel/(precision+rappel)
print(f1)
# Out:
# 351
# 637
# 988
# 0.811965811965812
# 0.4474097331240188
# 0.5769230769230769

# %% [markdown]
# # Comparaison des deux corpus texte par texte

# %% [markdown]
# ## Exactitude totale

# %% [markdown]
# ### Visualisation

# %%
def compare(first, second):
    commun = {}
    sharedKeys = set(first.keys()).intersection(second.keys())
    for key in sharedKeys:
        if first[key]==second[key]:
             commun[key] = ("Value 1: {}, Value 2: {}".format(first[key], second[key]))
    print("-------------------------")
    print("Puis les clés identiques dont les valeurs ne sont pas identiques :")
    for key in sharedKeys:
        if first[key] != second[key]:
    return (commun, len(commun))



i = 0
write_json("jsons_resultats/texteParTexte_CasENvsMano_tot/corpusEntier_exactitudeTotale_CasENvsMano.json", commun)

compare(dicoCasEN, dicoMano)

# %% [markdown]
# ### Calculs

# %% [markdown]
# ## Exactitude partielle

# %% [markdown]
# ### Visualisation

# %%
def compare(first, second):
    sharedKeys = set(first.keys()).intersection(second.keys())
    print("D'abord, toutes les clés identiques avec valeurs identiques : ")
    for key in sharedKeys:
        if first[key]==second[key]:
            print("Key: {}, Value 1: {}, Value 2: {}".format(key, first[key], second[key]))
    print("-------------------------")
    print("Puis les clés identiques dont les valeurs ne sont pas identiques :")
    for key in sharedKeys:
        if first[key] != second[key]:
            print("Key: {}, Value 1: {}, Value 2: {}".format(key, first[key], second[key]))
    diffKeys = set(first.keys()).difference(second.keys())
    print("-------------------------")
    print("Puis tout ce qui est différent :")
    for key in diffKeys:
        if key in first : 
            print("Key 1: {}, Value 1 : {}".format(key, first[key]))
        if key in second:
            print("Key 2: {} , Value 2: {}".format(key, second[key]))


k = 0

for i in liste_fic:
    k = k+1
    dicoCasEN = {}
    dicoMano = {}
    path_fic = folder1+i+ext1
    path_fic2 = folder2+i+ext2
    fic = ouvrir_json(path_fic)
    fic2 = ouvrir_json(path_fic2)
    for j in fic:
        dicoCasEN[j.strip()]=(fic[j]).strip()
    for j in fic2:
        dicoMano[j.strip()]=(fic2[j]).strip()
    sorted(dicoCasEN.items(), key=lambda t: t[0])
    sorted(dicoMano.items(), key=lambda t: t[0])
    print("\n ----------- \n Texte n° {} : {}".format(k, i))
    compare(dicoCasEN, dicoMano)

# %% [markdown]
# ### Calculs
