# %% [markdown]
# # Initialisation

# %%
import spacy

# %%
from spacy.lang.fr import French

# %%
nlp = French()

# %%
import glob, re

# %%
print(glob.glob('*'))
# Out:
# ['Tableur textes _ recueil de données.ods', 'traitementAnnotationsCasEN.ipynb', 'Débuts avec Spacy.ipynb', 'annotations_spacy_v1', 'quaero-guide-annotation-2011.pdf', 'CasEN en Unitex', 'traitementAnnotationsSpaCy.ipynb', 'Prise EN Main Unitex', 'annotations_casEN_scripts_v1', 'Textes', 'Introduction à Spacy.ipynb']

# %%
nlp2 = spacy.load("fr_core_news_sm")

# %%
def ecrire_fichier(chemin, liste):
    w = open(chemin, "w", encoding="utf-8")
    for i in liste:
        w.write("%s \t %s\n"%i)
    w.close()

# %%
def trouve_entite(doc, nom_fichier):
    liste = []
    for ent in doc.ents :
        contenu = (ent.text, ent.label_)
        liste.append(contenu)
    ecrire_fichier("annotations_spacy_v1/%s_anno_spacy.txt" %nom_fichier, liste)

# %% [markdown]
# # Essai sur CorpusAPIL.txt

# %%
nom_fichier1 = "annotations_spacy_v1/%s"
my_file = open(nom_fichier1%"CorpusAPIL_test.sample.txt", "r")
text = my_file.read()

# %%
# on process le texte
doc = nlp2(text)

for token in doc:
    # Get the token text, part-of-speech tag and dependency label
    token_text = token.text
    token_pos = token.pos_
    token_dep = token.dep_
    # This is for formatting only
    print(f"{token_text:<12}{token_pos:<10}{token_dep:<10}")
# Out:
# ERVY-LE-CHATELNOUN      ROOT
# –           PUNCT     ROOT
# 2ème        NUM       nummod
# jour        NOUN      obl:mod
# du          DET       case
# Marché      NOUN      nmod
# du          DET       case
# Livre       NOUN      nmod
# à           ADP       case
# la          DET       det
# salle       NOUN      nmod
# des         ADP       case
# fêtes       NOUN      nmod
# de          ADP       case
# 10          NUM       nummod
# h           NOUN      nmod
# à           ADP       case
# 18          NUM       dep
# h.          NOUN      dep
# Rencontres  PROPN     ROOT
# avec        ADP       case
# les         DET       det
# auteurs     NOUN      nmod
# ,           PUNCT     punct
# lectures    ADJ       appos
# entre       ADP       case
# 12          NUM       nummod
# h           NOUN      nmod
# et          CCONJ     cc
# 14          NUM       conj
# h.          NOUN      flat:name
# Organisée   VERB      ROOT
# par         ADP       case
# «           PUNCT     punct
# Ervy-le-ChâtelADJ       obl:agent
# ,           PUNCT     punct
# village     NOUN      obl:mod
# du          DET       case
# livre       NOUN      nmod
# et          CCONJ     cc
# des         ADP       case
# arts        NOUN      conj
# »           ADJ       punct
# 03          DET       ROOT
# 25          DET       nmod
# 76          DET       nmod
# 88          DET       nmod
# 78          NUM       nmod
# .           PUNCT     punct
#
#            SPACE
# 23          NUM       ROOT
# juillet     NOUN      nmod
# :           PUNCT     punct
# LIGNIERES   NOUN      nmod
# –           PUNCT     ROOT
# Reconnaître NOUN      ROOT
# 5           NUM       nummod
# sauvageonnesNOUN      obj
# comestibles ADJ       flat:foreign
# .           PUNCT     punct
# Savoir      VERB      ROOT
# les         PRON      obj
# utiliser    VERB      xcomp
# et          CCONJ     cc
# les         PRON      obj
# cuisiner    VERB      conj
# .           PUNCT     punct
# Organisé    VERB      ROOT
# par         ADP       case
# Les         DET       det
# Ombelles    NOUN      obl:agent
# 03          NUM       nummod
# 25          DET       nmod
# 43          DET       nmod
# 92          DET       nmod
# 26          NUM       nmod
# ou          CCONJ     cc
# www.lesombelles.comNUM       conj
#
#            SPACE
# Octobre     NOUN      nmod
# 2011        NUM       nmod
#
#            SPACE
# 15          NUM       nmod
# septembre   NOUN      nmod
# :           PUNCT     punct
# Sortie      NOUN      ROOT
# au          DET       case
# départ      NOUN      nmod
# d’          VERB      acl
# AIX-EN-OTHE PROPN     dep
# –           PUNCT     dep
# Sortie      NOUN      obl:agent
# au          DET       case
# Musée       NOUN      obl:arg
# Colette     PROPN     flat:name
# et          CCONJ     cc
# Château     NOUN      conj
# de          ADP       case
# Guédelon    PROPN     nmod
# .           PUNCT     punct
# Organisé    VERB      ROOT
# par         ADP       case
# le          DET       det
# Club        NOUN      obl:agent
# des         ADP       case
# Anciens     NOUN      nmod
# et          CCONJ     cc
# de          ADP       case
# amis        NOUN      conj
# d’          VERB      punct
# Aix         PROPN     ROOT
# 06          DET       nummod
# 75          PRON      dep
#             SPACE
# 15          DET       nmod
# 06          DET       nummod
# 14          NUM       nmod
# .           PUNCT     ROOT
#
#            SPACE
# 10          NUM       ROOT
# et          CCONJ     cc
# 11          NUM       conj
# décembre    NOUN      nmod
# :           PUNCT     punct
# BOUILLY     NOUN      nmod
# –           PUNCT     punct
# Marché      NOUN      ROOT
# de          ADP       case
# Noël        PROPN     nmod
# au          DET       case
# foyer       NOUN      nmod
# familial    ADJ       amod
# ,           PUNCT     punct
# organisé    VERB      acl
# par         ADP       case
# le          DET       det
# Comité      NOUN      obl:agent
# des         ADP       case
# fêtes       NOUN      nmod
# .           PUNCT     punct
#
#            SPACE
# ERVY-LE-CHATELNOUN      dep
# –           PROPN     dep
# Récital     NOUN      ROOT
# de          ADP       case
# Piano       PROPN     nmod
# 4           NUM       nummod
# mains       NOUN      acl
# avec        ADP       case
# Matthieu    PROPN     nmod
# Normand     PROPN     flat:name
# et          CCONJ     cc
# Nicolas     PROPN     conj
# Collinet    PROPN     flat:name
# à           ADP       case
# la          DET       det
# Halle       NOUN      nmod
# Circulaire  PROPN     nmod
# à           ADP       case
# 20          NUM       nummod
# h           NOUN      nmod
# 30          NUM       nummod
# .           PUNCT     punct
# Organisé    VERB      ROOT
# par         ADP       case
# Villa       PROPN     obl:mod
# de          ADP       case
# l'          DET       det
# Extra       NOUN      nmod
# 03          NUM       obl:mod
# 25          DET       nmod
# 43          DET       nmod
# 22          DET       nmod
# 10          DET       nmod
# ou          CCONJ     cc
# 06          DET       conj
# 79          DET       case
# 07          DET       nmod
# 79          NUM       nmod
# 25          NUM       nmod
# ou          CCONJ     cc
# http://villa-de-l-extra.skyrock.com/NOUN      conj
#
#            SPACE
# 16          NUM       nmod
# juillet     NOUN      nmod
# :           PUNCT     punct
# BERULLE     PROPN     dep
# -           PROPN     dep
# Randonnée   VERB      ROOT
# de          ADP       case
# 9           NUM       nummod
# h           NOUN      dep
# 30          NUM       nummod
# à           ADP       case
# 18          NUM       nmod
# h           NOUN      nmod
# (           PUNCT     punct
# prévoir     VERB      acl
# pique-nique NOUN      amod
# )           PUNCT     punct
# «           PUNCT     punct
# Une         DET       det
# seconde     ADJ       amod
# vie         NOUN      ROOT
# pour        ADP       case
# des         DET       det
# arbres      NOUN      nmod
# »           DET       punct
# Départ      NOUN      nmod
# et          CCONJ     cc
# retour      NOUN      conj
# à           ADP       case
# Bérulle     PROPN     nmod
# .           PUNCT     punct
# ParticipationNOUN      ROOT
# 5           NUM       nummod
# €           NOUN      nmod
# et          CCONJ     cc
# 3           NUM       nummod
# €           NOUN      conj
# (           PUNCT     punct
# adhérents   NOUN      appos
# )           PUNCT     punct
# .           PUNCT     punct
# InscriptionsNOUN      ROOT
# 03          DET       ROOT
# 25          DET       nmod
# 70          DET       dep
# 03          DET       nmod
# 05          PRON      nmod
# .           PUNCT     punct
#
#            SPACE
# BOUILLY     PROPN     ROOT
# –           PUNCT     punct
# Téléthon    NOUN      ROOT
# au          DET       case
# foyer       NOUN      nmod
# familial    ADJ       amod
# organisé    VERB      acl
# par         ADP       case
# le          DET       det
# CCAS        NOUN      obl:agent
# .           PUNCT     punct
#
#            SPACE
# CHAOURCE    NOUN      ROOT
# –           PUNCT     punct
# Concert     PROPN     ROOT
# d’          VERB      flat:name
# orgue       VERB      acl
# à           ADP       case
# l’          NOUN      obl:arg
# église      VERB      amod
# par         ADP       case
# Paul        PROPN     nmod
# Breisch     PROPN     flat:name
# de          ADP       case
# la          DET       det
# cathédrale  NOUN      nmod
# de          ADP       case
# Luxembourg  PROPN     nmod
# .           PUNCT     punct
# Concert     VERB      ROOT
# à           ADP       case
# 17          NUM       dep
# h.          NOUN      nmod
#
#            SPACE
# 23          NUM       nmod
# juin        NOUN      nmod
# au          DET       case
# 7           NUM       nmod
# juillet     NOUN      nmod
# :           PUNCT     punct
# Cabaret     PROPN     mark
# itinérant   VERB      ROOT
# du          DET       case
# Festival    NOUN      nmod
# en          ADP       case
# Othe        PROPN     nmod
# .           PUNCT     punct
# Programme   VERB      ROOT
# sur         ADP       case
# le          DET       det
# www.festivalenothe.orgNOUN      nmod
#
#            SPACE
# VAUCHASSIS  PROPN     ROOT
# –           PROPN     punct
# 41ème       NUM       nummod
# fête        NOUN      ROOT
# du          DET       case
# cidre       NOUN      nmod
#
#            SPACE
# Du          DET       case
# 9           NUM       nmod
# au          DET       case
# 11          NUM       nmod
# septembre   NOUN      nmod
# :           PUNCT     punct
# ERVY-LE-CHATELNOUN      dep
# –           PROPN     dep
# Stage       NOUN      nmod
# d’          PROPN     nmod
# Aquarelle   PROPN     ROOT
# organisé    VERB      acl
# par         ADP       case
# Sylvie      PROPN     obl:agent
# Vernageau   PROPN     flat:name
# .           PUNCT     punct
# Stage       NOUN      ROOT
# intensif    ADJ       amod
# de          ADP       case
# 9           NUM       nummod
# h           NOUN      obl:arg
# 30          NUM       nummod
# à           ADP       case
# 12          NUM       nmod
# h           NOUN      nmod
# 30          NUM       nummod
# et          CCONJ     cc
# de          ADP       case
# 14          NUM       nummod
# h           NOUN      conj
# 30          NUM       nummod
# à           ADP       case
# 18          NUM       nmod
# h.          NOUN      nmod
# Tarif       PROPN     flat:name
# :           PUNCT     punct
# 150         NUM       nummod
# €           NOUN      ROOT
# .           PUNCT     punct
# RéservationsNOUN      ROOT
# et          CCONJ     cc
# informationsNOUN      conj
# au          DET       case
# 03          DET       nummod
# 25          DET       nmod
# 42          DET       nmod
# 10          DET       nmod
# 46          DET       nmod
# ou          CCONJ     cc
# 06          DET       conj
# 82          DET       nmod
# 96          DET       nmod
# 92          DET       nmod
# 24          NUM       nmod
# .           PUNCT     punct
#
#            SPACE
# MARAYE-EN-OTHENOUN      dep
# –           PUNCT     dep
# Feux        PROPN     ROOT
# de          ADP       case
# la          DET       det
# Saint-Jean  PROPN     nmod
# au          DET       mark
# lavoir      NOUN      advcl
# des         DET       det
# boulins     NOUN      obj
# à           ADP       case
# 19          NUM       dep
# h.          NOUN      obl:mod
# Animations  NOUN      ROOT
# musicales   ADJ       amod
# ,           PUNCT     punct
# restaurationNOUN      amod
# sur         ADP       case
# place       NOUN      nmod
# .           PUNCT     punct
# Organisé    VERB      ROOT
# par         ADP       case
# Maraye      PROPN     obl:agent
# Pour        ADP       case
# Tous        ADJ       amod
# 03          DET       dep
# 25          DET       obl:mod
# 80          DET       nmod
# 75          DET       dep
# 69          DET       nmod
#
#            SPACE
# RACINES     PROPN     nmod
# –           PROPN     punct
# Soirée      PROPN     nmod
# «           PUNCT     nmod
# Entre       ADP       case
# France      PROPN     nmod
# et          CCONJ     cc
# Russie      PROPN     conj
# »           PUNCT     punct
# dans        ADP       case
# l’          NOUN      obl:mod
# église      ADJ       amod
# à           ADP       case
# 20          NUM       nummod
# h           NOUN      nmod
# 30          NUM       nummod
# .           PUNCT     punct
# Concert     ADJ       ROOT
# :           PUNCT     punct
# mélodies    NOUN      appos
# slaves      ADJ       flat:name
# ,           PUNCT     punct
# chansons    NOUN      conj
# russes      ADJ       amod
# et          CCONJ     cc
# françaises  ADJ       conj
# avec        ADP       case
# Philippe    PROPN     nmod
# Borecek     PROPN     flat:name
# (           PUNCT     punct
# accordéonisteADJ       amod
# )           PUNCT     punct
# et          CCONJ     cc
# Ivan        X         conj
# Netchiporko PROPN     flat:name
# (           PUNCT     punct
# ténor       NOUN      appos
# )           PUNCT     punct
# .           PUNCT     punct
# Organisée   VERB      ROOT
# par         ADP       case
# «           PUNCT     punct
# Ervy-le-ChâtelADJ       obl:agent
# ,           PUNCT     punct
# village     NOUN      appos
# du          DET       case
# livre       NOUN      nmod
# et          CCONJ     cc
# des         ADP       case
# arts        NOUN      conj
# »           ADJ       punct
# 03          DET       ROOT
# 25          DET       nmod
# 76          DET       nmod
# 88          DET       nmod
# 78          NUM       nmod
# .           PUNCT     punct
#
#            SPACE
# ESTISSAC    NOUN      ROOT
# –           PUNCT     punct
# Fête        NOUN      ROOT
# du          DET       case
# Cochon      PROPN     nmod
# sur         ADP       case
# la          DET       det
# place       NOUN      nmod
# Caroline    ADJ       nmod
# .           PUNCT     punct
#
#            SPACE
# 26          NUM       ROOT
# août        NOUN      nmod
# :           PUNCT     punct
# PALIS       NOUN      nmod
# –           PUNCT     punct
# Concours    PROPN     nsubj:pass
# d’          VERB      flat:name
# été         AUX       aux:pass
# organisé    VERB      ROOT
# par         ADP       case
#             SPACE
# la          DET       det
# Boule       PROPN     obl:agent
# Palisienne  VERB      amod
# sur         ADP       case
# inscription NOUN      nmod
# au          DET       case
# 06          DET       nummod
# 01          DET       nummod
# 71          DET       dep
# 82          DET       nmod
# 17          PRON      nmod
# .           PUNCT     punct
#
#            SPACE
# LIGNIERES   PROPN     dep
# –           PUNCT     dep
# Fête        NOUN      ROOT
# du          DET       case
# tilleul     NOUN      nmod
# centenaire  ADJ       amod
# .           PUNCT     punct
# RenseignementsNOUN      ROOT
# au          DET       case
# 03          DET       nummod
# 25          DET       nmod
# 43          DET       nummod
# 92          DET       nmod
# 26          NUM       nmod
# ou          CCONJ     cc
# www.lesombelles.comNUM       conj
#
#            SPACE
# EAUX        PROPN     nmod
# -           PUNCT     punct
# PUISEAUX    PROPN     ROOT
# –           PROPN     punct
# Promenade   VERB      ROOT
# dans        ADP       case
# l’          PROPN     nmod
# Aube        PROPN     ROOT
# avec        ADP       case
# le          DET       det
# groupe      NOUN      dep
# Akadêmia    ADJ       nmod
# au          DET       case
# Musée       NOUN      nmod
# du          DET       case
# Cidre       PROPN     nmod
# (           PUNCT     punct
# 22          NUM       dep
# rue         NOUN      nmod
# Largentier)àADP       nmod
# 19          NUM       nmod
# h.          NOUN      ROOT
# RenseignementsNOUN      ROOT
# 03          PRON      ROOT
# 26          DET       nmod
# 55          DET       nmod
# 71          DET       dep
# 80          PRON      dep
# www.akademia.frPROPN     nmod
#
#            SPACE
# Juillet     NOUN      nmod
# 2011        NUM       nmod
# :           PUNCT     punct
# ESSOYES     NOUN      ROOT
# –           PUNCT     punct
# Exposition  NOUN      ROOT
# permanente  ADJ       amod
# de          ADP       case
# M.          NOUN      nmod
# Monnet      PROPN     flat:name
# Pierre      PROPN     flat:name
# ,           PUNCT     punct
# peintre     ADJ       appos
# du          DET       case
# Pays        NOUN      nmod
# d’          PROPN     nmod
# Armance     PROPN     ROOT
# «           PUNCT     punct
# Au          DET       case
# fil         NOUN      ROOT
# de          ADP       case
# l’          PROPN     nmod
# Ours        PROPN     flat:name
# ,           PUNCT     punct
# dans        ADP       case
# les         DET       det
# pas         NOUN      nmod
# de          ADP       mark
# Renoir      VERB      nmod
# »           VERB      punct
# à           ADP       case
# l’          NOUN      nmod
# atelier     ADJ       amod
# du          DET       case
# 2           NUM       nummod
# rue         NOUN      nmod
# du          DET       case
# four        NOUN      nmod
# .           PUNCT     punct
#
#            SPACE
# BOUILLY     PROPN     ROOT
# –           PUNCT     punct
# Journées    PROPN     ROOT
# du          DET       case
# Patrimoine  NOUN      nmod
# ,           PUNCT     punct
# visite      NOUN      nmod
# de          ADP       case
# l’          NOUN      nmod
# église      ADJ       amod
# Saint       PROPN     amod
# Laurent     PROPN     flat:name
# organisée   VERB      acl
# par         ADP       case
# la          DET       det
# Commission  NOUN      obl:agent
# de          ADP       case
# la          DET       det
# Culture     PROPN     nmod
# .           PUNCT     punct
#
#            SPACE
# MAROLLES-SOUS-LIGNIERESPROPN     dep
# –           PUNCT     dep
# Méchoui     NOUN      ROOT
# à           ADP       case
# la          DET       det
# salle       NOUN      nmod
# des         ADP       case
# fêtes       NOUN      nmod
# organisé    VERB      acl
# par         ADP       case
# le          DET       det
# comité      NOUN      obl:agent
# des         ADP       case
# fêtes       NOUN      nmod
# 03          PRON      obl:mod
# 25          DET       nmod
# 76          DET       nmod
# 01          DET       nmod
# 38          NUM       nmod
# .           PUNCT     punct
#
#            SPACE
# 4           NUM       nmod
# septembre   NOUN      nmod
# :           PUNCT     punct
# AUXON       PROPN     ROOT
# –           PUNCT     punct
# Vide        NOUN      ROOT
# grenier     NOUN      amod
# .           PUNCT     punct
# Organisé    VERB      ROOT
# par         ADP       case
# l’          NUM       obl:agent
# AFCA        PROPN     nmod
# 03          NOUN      ROOT
# 25          DET       nmod
# 42          DET       nmod
# 03          DET       nmod
# 62          PRON      nmod
# .           PUNCT     punct
#
#            SPACE
# BERULLE     PROPN     dep
# -           PROPN     punct
# à           ADP       case
# 18          NUM       nummod
# h           NOUN      obl:mod
# profitez    ADJ       ROOT
# des         DET       det
# conditions  NOUN      obj
# de          ADP       case
# l’          PROPN     nmod
# Espace      PROPN     ROOT
# Jean        PROPN     flat:foreign
# Musy        PROPN     flat:name
# pour        ADP       mark
# faire       VERB      parataxis
# un          DET       det
# passage     NOUN      obj
# sur         ADP       case
# scène       NOUN      nmod
# :           PUNCT     punct
# musique     NOUN      obj
# ,           PUNCT     punct
# poésie      NOUN      nmod
# ,           PUNCT     punct
# danse       NOUN      conj
# ,           PUNCT     punct
# sketchs     NOUN      conj
# ,           PUNCT     punct
# acrobatie   NOUN      nmod
# ,           PUNCT     punct
# etc.        ADV       nmod
# Une         DET       det
# soirée      NOUN      ROOT
# unique      ADJ       amod
# chaque      DET       det
# année       NOUN      nmod
# !           PUNCT     punct
# Scène       NOUN      ROOT
# ouverte     ADJ       acl
# à           ADP       case
# tous        ADJ       obl:arg
# sur         ADP       case
# inscription NOUN      obl:mod
# uniquement  ADV       advmod
# 03          DET       nummod
# 25          DET       nmod
# 42          DET       nmod
# 59          DET       dep
# 34          NOUN      dep
# –           PUNCT     nmod
# entrée      NOUN      nmod
# libre       ADJ       amod
# ,           PUNCT     punct
# tout        DET       det
# public      NOUN      nmod
# .           PUNCT     punct
#
#            SPACE
# 24          NUM       ROOT
# août        NOUN      nmod
# :           PUNCT     punct
# PALIS       NOUN      nmod
# –           PUNCT     punct
# Concours    PROPN     nsubj:pass
# d’          VERB      flat:name
# été         AUX       aux:pass
# organisé    VERB      ROOT
# par         ADP       case
#             SPACE
# la          DET       det
# Boule       PROPN     obl:agent
# Palisienne  VERB      amod
# sur         ADP       case
# inscription NOUN      nmod
# au          DET       case
# 06          DET       nummod
# 01          DET       nummod
# 71          DET       dep
# 82          DET       nmod
# 17          PRON      nmod
# .           PUNCT     punct
#
#            SPACE
# ESTISSAC    NOUN      ROOT
# –           PUNCT     punct
# Rando       NOUN      ROOT
# Voirloups   PROPN     flat:name
# ,           PUNCT     punct
# randonnée   VERB      nmod
# cyclo       DET       amod
# ,           PUNCT     punct
# VVT         PROPN     nmod
# et          CCONJ     cc
# pédestre    NOUN      conj
# .           PUNCT     punct
# Départ      NOUN      ROOT
# de          ADP       case
# l’          NUM       nmod
# école       NOUN      ROOT
# primaire    ADJ       amod
# d’          VERB      acl
# Estissac    NOUN      ROOT
# à           ADP       advmod
# partir      VERB      fixed
# de          ADP       case
# 7           NUM       nummod
# h           NOUN      dep
# 30          NUM       nummod
# .           PUNCT     punct
# Randonnée   VERB      ROOT
# sur         ADP       case
# circuits    NOUN      nmod
# balisés     VERB      acl
# avec        ADP       case
# ravitaillementNOUN      nmod
# en          ADP       case
# cours       NOUN      nmod
# de          ADP       case
# route       NOUN      nmod
# et          CCONJ     cc
# verre       NOUN      conj
# de          ADP       case
# cidre       VERB      nmod
# à           ADP       case
# l’          NUM       nmod
# arrivée     NOUN      amod
# .           PUNCT     punct
# Organisé    VERB      ROOT
# par         ADP       case
# le          DET       det
# Cyclo       PROPN     obl:agent
# Club        PROPN     appos
# Othéen      NOUN      ROOT
# 03          NUM       nummod
# 25          DET       nmod
# 40          DET       nmod
# 61          DET       nmod
# 67          NUM       nmod
# .           PUNCT     punct
#
#            SPACE
# COUSSEGREY  PROPN     ROOT
# –           PROPN     punct
# Stage       NOUN      ROOT
# être        AUX       aux:pass
# soi         NOUN      ROOT
# dans        ADP       case
# l’          NUM       obl:arg
# univers     PROPN     amod
# .           PUNCT     punct
# Ce          DET       det
# stage       NOUN      nsubj
# vous        PRON      nsubj
# propose     VERB      ROOT
# une         DET       det
# exploration NOUN      obj
# à           ADP       case
# travers     NOUN      amod
# l’          PROPN     obl:arg
# Univers     PROPN     flat:name
# ,           PUNCT     punct
# l’          PROPN     obl:mod
# espace      PROPN     amod
# ,           PUNCT     punct
# le          DET       det
# temps       NOUN      obl:mod
# ,           PUNCT     punct
# et          CCONJ     cc
# la          DET       det
# matière     NOUN      conj
# picturale   ADJ       amod
# (           PUNCT     punct
# dessin      PROPN     dep
# -           PROPN     dep
# peinture    NOUN      dep
# -           PUNCT     dep
# collage     NOUN      appos
# )           PUNCT     punct
# ,           PUNCT     punct
# pour        ADP       case
# un          DET       det
# véritablevoyageNOUN      obl:mod
# au          DET       case
# centre      NOUN      nmod
# de          ADP       case
# Soi         PROPN     nmod
# ,           PUNCT     punct
# à           ADP       advmod
# partir      VERB      fixed
# des         ADP       det
# contes      NOUN      dep
# ,           PUNCT     punct
# des         DET       case
# légendes    NOUN      obl:mod
# ,           PUNCT     punct
# et          CCONJ     cc
# de          ADP       case
# la          DET       det
# création    NOUN      conj
# artistique  ADJ       amod
# .           PUNCT     punct
# Tarif       NOUN      ROOT
# 355         NUM       nummod
# €           NOUN      nmod
# .           PUNCT     punct
# RenseignementsNOUN      ROOT
# au          DET       case
# 03          DET       nummod
# 25          DET       nmod
# 70          DET       nummod
# 69          DET       nmod
# 35          NUM       nmod
# ou          CCONJ     cc
# www.laurier-rouge.comNOUN      conj
#
#            SPACE
# Du          DET       case
# 8           PRON      nmod
# au          DET       case
# 15          NUM       nmod
# août        NOUN      nmod
# :           PUNCT     punct
# LIGNIERES   NOUN      ROOT
# –           PUNCT     dep
# Chantier    PROPN     ROOT
# ouvert      VERB      amod
# à           ADP       case
# tous        ADJ       nmod
# pour        ADP       mark
# apprendre   VERB      advcl
# ,           PUNCT     punct
# comprendre  VERB      conj
# ,           PUNCT     punct
# aider       VERB      xcomp
# en          ADP       case
# éco         NOUN      amod
# constructionNOUN      obl:arg
# .           PUNCT     punct
# Organisé    VERB      ROOT
# par         ADP       case
# Les         DET       det
# Ombelles    NOUN      obl:agent
# 03          NUM       obl:mod
# 25          DET       nmod
# 43          DET       nummod
# 92          DET       nmod
# 26          NUM       nmod
# ou          CCONJ     cc
# www.lesombelles.comNUM       conj
#
#            SPACE
# 8           NUM       nmod
# septembre   NOUN      nmod
# :           PUNCT     punct
# SORMERY     NOUN      ROOT
# -           PUNCT     punct
# Café        PROPN     ROOT
# Surprise    PROPN     flat:name
# :           PUNCT     punct
# pratique    NOUN      nmod
# artistique  ADJ       amod
# et          CCONJ     cc
# chansons    NOUN      conj
# ,           PUNCT     punct
# buffet      VERB      nmod
# à           ADP       case
# 19          NUM       nummod
# h           NOUN      nmod
# .           PUNCT     punct
# 15          NUM       nummod
# €           NOUN      nmod
# /           ADP       cc
# diner       NUM       nmod
# inclus      NOUN      ROOT
# .           PUNCT     punct
# Organisé    VERB      ROOT
# par         ADP       case
# le          DET       det
# Couvent     NOUN      obl:agent
# de          ADP       case
# l’          PROPN     nmod
# Orée        NOUN      appos
# Contact     PROPN     flat:name
# :           PUNCT     punct
# 03          NOUN      nmod
# 86          DET       nmod
# 56          DET       nmod
# 32          DET       nmod
# 73          NUM       nmod
#             SPACE
# www.paciflore.comNOUN      nmod
#
#            SPACE
# Du          DET       case
# 24          PRON      nmod
# au          DET       case
# 26          NUM       nmod
# juin        NOUN      nmod
# :           PUNCT     punct
# ERVY-LE-CHATELNOUN      ROOT
# –           PROPN     punct
# Stage       NOUN      nmod
# d’          PROPN     nmod
# Aquarelle   PROPN     ROOT
# à           ADP       case
# l’          NOUN      nmod
# Atelier     NOUN      nmod
# de          ADP       case
# Sylvie      PROPN     nmod
# Vernageau   PROPN     flat:name
# .           PUNCT     punct
# Stage       NOUN      ROOT
# de          ADP       case
# 9           NUM       nummod
# h           NOUN      nmod
# 30          NUM       nummod
# à           ADP       case
# 12          NUM       nmod
# h           NOUN      nmod
# 30          NUM       nummod
# et          CCONJ     cc
# de          ADP       case
# 14          NUM       nummod
# h           NOUN      conj
# 30          NUM       nummod
# à           ADP       case
# 18          NUM       nmod
# h.          NOUN      nmod
# Tarif       PROPN     flat:name
# :           PUNCT     punct
# 150         NUM       nummod
# €           NOUN      ROOT
# .           PUNCT     punct
# RéservationsNOUN      ROOT
# et          CCONJ     cc
# informationsNOUN      conj
# au          DET       case
# 03          DET       nummod
# 25          DET       nmod
# 42          DET       nmod
# 10          DET       nmod
# 46          DET       nmod
# ou          CCONJ     cc
# 06          DET       conj
# 82          DET       nmod
# 96          DET       nmod
# 92          DET       nmod
# 24          NUM       nmod
# .           PUNCT     punct
#
#            SPACE

# %%
for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
# Out:
#
# AIX-EN-OTHE – Exposition des collages et coloriages 7150 7201 MISC
# Catherine Chevreau 7205 7223 PER
# VILLEMAUR-SUR-VANNE 7289 7308 MISC
# Othe 7337 7341 LOC
# Nicolaï Cok 7363 7374 PER
# Du 4 7397 7401 MISC
# AUXON 7418 7423 ORG
# Centre 7426 7432 LOC
# Enfants 7470 7477 LOC
# Familles 7481 7489 LOC
# OTHE 7541 7545 ORG
# Pays d’Othe 7583 7594 LOC
# ERVY-LE-CHATEL 7678 7692 LOC
# Akadêmia 7732 7740 ORG
# Halle Circulaire 7746 7762 LOC
# Champagne 7832 7841 LOC
# Ardenne 7842 7849 LOC
# Akadêmia 8130 8138 PER
# Echappée Belle 8153 8167 MISC
# EAUX 8215 8219 ORG
# PUISEAUX 8220 8228 MISC
# Promenade 8231 8240 LOC
# Akadêmia 8268 8276 ORG
# Musée du Cidre 8280 8294 LOC
# Largentier)à 8303 8315 MISC
# Renseignements 8322 8336 ORG
# LIGNIERES 8387 8396 MISC
# Autoconstruction Organisé 8399 8424 ORG
# LES OMBELLES 8443 8455 ORG
# Le Solaire 8493 8503 LOC
# » et « Un ballon 8525 8541 MISC
# Michel » 8547 8555 PER
# ERVY-LE-CHATEL – Stage d’ 8614 8639 MISC
# Sylvie Vernageau 8662 8678 PER
# Tarif 8737 8742 LOC
# Réservations 8752 8764 LOC
# AIX-EN-OTHE - Journées Maboul 8819 8848 MISC
# Festival 8852 8860 MISC
# Othe 8864 8868 LOC
# CHESSY-LES-PRES – Portes Ouvertes 8931 8964 MISC
# Atelier Cypraea 8970 8985 PER
# Visites d’Entreprises 9056 9077 ORG
# Ervy-le-Châtel 9196 9210 LOC
# Concert 9213 9220 LOC
# Listz 9228 9233 PER
# Lamartine 9244 9253 PER
# Villa 9304 9309 PER
# Extra 9315 9320 LOC
# ERVY-LE-CHATEL 9371 9385 MISC
# Les Randonneurs Ervytains 9626 9651 MISC
# VOSNON 9668 9674 MISC
# Course 9677 9683 MISC
# Vosnon Loisirs 9741 9755 PER
# l’Amicale 9774 9783 MISC
# Sapeurs Pompiers 9788 9804 MISC
# Concert 9832 9839 ORG
# Micha Novenko 9863 9876 PER
# Cathédrale Saint-Guy de Prague 9883 9913 LOC
# PRUSY 9931 9936 ORG
# Concours de pêche Individuel 9939 9967 ORG
# COUSSEGREY 10087 10097 MISC
# Stage Co-animé Intuitions 10100 10125 MISC
# Créativité 10129 10139 LOC
# C’ 10141 10143 MISC
# Tarif 10278 10283 LOC
# PALIS 10370 10375 ORG
# Stage d’initiation au papier végétal 10378 10414 MISC
# Contact Jean-François Havet 10652 10679 PER
# Voyage au départ 10745 10761 MISC
# Aix-en-Othe – Croisière 10764 10787 PER
# Rhin 10795 10799 LOC
# Club des Anciens 10817 10833 MISC
# Amis d’ 10841 10848 ORG
# Festi'Coccinelle 10903 10919 PER
# VOSNON – Méchoui 11067 11083 PER
# Vosnon Loisirs 11111 11125 PER
# l’Amicale 11144 11153 MISC
# Sapeurs Pompiers 11158 11174 MISC
# COURSAN-EN-OTHE – Retraite 11206 11232 MISC
# AUXON 11329 11334 ORG
# ERVY-LE-CHATEL – Rencontre 34273 34299 MISC
# Rostislav Loukine 34379 34396 PER
# Grégoire Michonze 34400 34417 PER
# Médiathèque 34423 34434 LOC
# « Ervy-le-Châtel 34458 34474 LOC
# Village 34476 34483 LOC
# Livre et des Arts » 34487 34506 LOC
# Octobre 34526 34533 LOC
# L’ 34551 34553 LOC
# Chaource 34737 34745 LOC
# CIEBA 34776 34781 ORG
# ERVY-LE-CHATEL 34798 34812 MISC
# Inauguration 34815 34827 MISC
# RACINES 34922 34929 ORG
# Soirée « 34932 34940 LOC
# France 34947 34953 LOC
# Russie 34957 34963 LOC
# Philippe Borecek 35053 35069 PER
# Ivan Netchiporko 35089 35105 PER
# « Ervy-le-Châtel 35129 35145 LOC
# Initiation 35393 35403 LOC
# René Prestat 35433 35445 PER
# Apprentis 35569 35578 PER
# CIEBA 35642 35647 ORG
# ERVY-LE-CHATEL 35688 35702 MISC
# Exposition d’ 35705 35718 MISC
# Halle Circulaire 35759 35775 LOC
# Artiste Roumaine 35792 35808 PER
# « Ervy-le-Châtel 35865 35881 LOC
# CUSSANGY 35944 35952 MISC
# ERVY-LE-CHATEL 36004 36018 MISC
# Marché du Livre 36034 36049 MISC
# Rencontres 36087 36097 LOC
# Organisée 36145 36154 LOC
# « Ervy-le-Châtel 36159 36175 LOC
# VAUCHASSIS 36224 36234 MISC
# Bourse 36287 36293 LOC
# ESTISSAC 36388 36396 MISC
# Bourse 36533 36539 LOC
# AUXON 36667 36672 ORG
# CIEBA 36692 36697 ORG
# Escapade 36700 36708 MISC
# CIEBA 36941 36946 ORG
# CIEBA 36964 36969 ORG
# Société auboise de botanique 37156 37184 ORG
# CIEBA 37215 37220 ORG
# COURSAN-EN-OTHE 37238 37253 MISC
# VOSNON 37326 37332 MISC
# Repas 37335 37340 LOC
# Vosnon Loisirs 37365 37379 PER
# LANTAGES – Loto 37410 37425 MISC
# Initiation 37440 37450 ORG
# Organisé 37476 37484 LOC
# ERVY-LE-CHATEL – Soirée 37556 37579 MISC
# France 37588 37594 LOC
# Russie 37598 37604 LOC
# Makarenko » 37623 37634 PER
# Halle Circulaire 37703 37719 LOC
# « Ervy-le-Châtel 37745 37761 LOC
# ERVY-LE-CHATEL 37810 37824 LOC
# Ciné-Concert 37827 37839 LOC
# Benjamin Intartaglia 37845 37865 PER
# Ragtime 37876 37883 PER
# Halle Circulaire 37890 37906 LOC
# Villa 37958 37963 PER
# Extra 37969 37974 LOC
# VAUCHASSIS 38048 38058 ORG
# Concours 38061 38069 MISC
# BOUILLY – Loto 38111 38125 LOC
# Comité des fêtes 38160 38176 ORG
# ERVY-LE-CHATEL 38193 38207 MISC
# Entrée gratuite 38299 38314 ORG
# Buvette 38316 38323 PER
# La Dynamic Ervytaine 38365 38385 MISC
# BUCEY-EN-OTHE 38438 38451 LOC
# Concert 38454 38461 LOC
# La Volière » 38491 38503 MISC
# Organisé 38512 38520 MISC
# Sauvegarde du Patrimoine de Bucey-en-Othe 38547 38588 ORG
# Assembler 38651 38660 PER
# Ligue de protection des oiseaux 38799 38830 ORG
# CIEBA 38861 38866 ORG
# Coursan-en-Othe 46183 46198 LOC
# COURSAN-EN-OTHE 46250 46265 MISC
# Participation au Téléthon 46268 46293 MISC
# Téléthon 46362 46370 PER
# Maraye Pour Tous 46440 46456 PER
# BOUILLY 46473 46480 ORG
# Sainte Barbe 46483 46495 PER
# Foyer familial 46499 46513 ORG
# RACINES 46575 46582 ORG
# CHENNEGY 46645 46653 ORG
# Téléthon 46656 46664 PER
# Après-midi 46694 46704 MISC
# Souvenirs – Souvenirs 46746 46767 ORG
# COUSSEGREY 46769 46779 ORG
# Randonnée 46782 46791 LOC
# Organisé 46801 46809 LOC
# Les Dagoniots 46828 46841 ORG
# BOUILLY 46899 46906 ORG
# Marché de Noël 46909 46923 MISC
# Comité des fêtes 46959 46975 ORG

# %%
trouve_entite(doc, "APIL_result")

# %% [markdown]
# # aijwikiner

# %%
nom_fichier1 = "annotations_spacy_v1/%s"
my_file = open(nom_fichier1%"aijwikiner.sample.txt", "r")
text = my_file.read()

# on process le texte
doc = nlp2(text)

trouve_entite(doc, "aijkwikiner_result.txt")

# %% [markdown]
# # GSD

# %%
nom_fichier1 = "annotations_spacy_v1/%s"
my_file = open(nom_fichier1%"fr_gsd-ud-train.conllu.sample.txt", "r")
text = my_file.read()

# on process le texte
doc = nlp2(text)

trouve_entite(doc, "GSD_result.txt")

# %% [markdown]
# # PG

# %%
nom_fichier1 = "annotations_spacy_v1/%s"
my_file = open(nom_fichier1%"pg6470.sample.txt", "r")
text = my_file.read()

# on process le texte
doc = nlp2(text)

trouve_entite(doc, "pg6470_result.txt")

# %% [markdown]
# # Sequoia

# %%
nom_fichier1 = "annotations_spacy_v1/%s"
my_file = open(nom_fichier1%"fr_sequoia-ud-train.conllu.sample.txt", "r")
text = my_file.read()

# on process le texte
doc = nlp2(text)

trouve_entite(doc, "Sequoia_result.txt")

# %% [markdown]
# # Spoken

# %%
nom_fichier1 = "annotations_spacy_v1/%s"
my_file = open(nom_fichier1%"fr_spoken-ud-train.conllu.sample.txt", "r")
text = my_file.read()

# on process le texte
doc = nlp2(text)

trouve_entite(doc, "spoken_result.txt")

# %% [markdown]
# # Wikinews

# %%
nom_fichier1 = "annotations_spacy_v1/%s"
my_file = open(nom_fichier1%"wikinews-2018-03.sample.txt", "r")
text = my_file.read()

# on process le texte
doc = nlp2(text)

trouve_entite(doc, "Wikinews_result.txt")

# %% [markdown]
# # Systématisation

# %%
liste_fichier= ["aijwikiner_result.txt", "APIL_result.txt", "GSD_result.txt", "pg6470_result.txt", "Sequoia_result.txt", "spoken_result.txt", "Wikinews_result.txt"]

# %%
for i in liste_fichier:
    path = "annotations_spacy_v1/%s_result.txt"%i
    mon_fichier2 = open(path, "r")
    text2 = mon_fichier2.read()
    doc2 = nlp2(text2)
    trouve_entite(doc2, i)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-51-a92e39fb2fe2> in <module>
#       1 for i in liste_fichier:
#       2     path = "annotations_spacy_v1/%s_result.txt"%i
# ----> 3     mon_fichier2 = open(path, "r")
#       4     text2 = mon_fichier2.read()
#       5     doc2 = nlp2(text2)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'annotations_spacy_v1/aijwikiner_result.txt_result.txt'
