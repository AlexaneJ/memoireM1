# %% [markdown]
# # Annotations CasEN

# %%
import xml.etree.ElementTree as ET
tree=ET.parse('aijwikiner_result.txt')

# %%
import codecs
import json

# %%
#import os
#import glob
#print(glob.glob('*'))

# %%
root=tree.getroot()
for texte in root.iter('s'):
    print(texte.text)
# Out:
#  Deux temps structurent l' œuvre, les cinquante

# %%
elemList=[]
for elem in tree.iter():
    if elem.tag not in elemList:
        elemList.append(elem.tag)
print(elemList)
# Out:
# ['s', 'measure', 'placeName', 'event', 'date', 'extent', 'persName', 'orgName', 'productName', 'title', 'roleName', 'org', 'region', 'geogName', 'geogFeat', 'offset', 'adress', 'adrLine', 'address-number', 'country', 'datePeriod', 'val']

# %%
def write_json(path, contenu):
    w = codecs.open(path, "w", encoding="utf-8")
    w.write(json.dumps(contenu, indent = 2, ensure_ascii=False))
    w.close()
    
def ouvrir_json(path):
    f = codecs.open(path, encoding="utf-8")
    toto = json.load(f)
    f.close()
    return toto

# %%
dico_anno = {}

for elem in tree.findall('orgName'):
    dico_anno[elem.tag] = elem.text
for elem in tree.findall('measure'):
    dico_anno[elem.tag] = elem.text
for elem in tree.findall('date'):
    if elem.tag != None:
        dico_anno[elem.tag] = elem.text
for elem in tree.findall('roleName'):
    dico_anno[elem.tag] = elem.text
for elem in tree.findall('org'):
    dico_anno[elem.tag] = elem.text
for elem in tree.findall('geogFeat'):
    if elem.text != None:
        dico_anno[elem.tag] = elem.text
for elem in tree.findall('geogName'):
    dico_anno[elem.tag] = elem.text
for elem in tree.findall('offset'):
    dico_anno[elem.tag] = elem.text
for elem in tree.findall('val'):
    dico_anno[elem.tag] = elem.text
for elem in tree.findall('placeName'):
    dico_anno[elem.tag] = elem.text
for elem in tree.findall('persName/forename'):
    dico_anno[elem.tag] = elem.text
for elem in tree.findall('persName/surname'):
    dico_anno[elem.tag] = elem.text
for elem in tree.findall('persName'):
    if elem.text != None:
        dico_anno[elem.tag] = elem.text
for elem in tree.findall('extent/measure'):
    dico_anno[elem.tag] = elem.text
for elem in tree.findall('adress/adrLine/address-number'):
    dico_anno[elem.tag] = elem.text
for elem in tree.findall('ref'):
    if elem.text != None:
        dico_anno[elem.tag] = elem.text
for elem in tree.findall('product'):
    dico_anno[elem.tag] = elem.text
for elem in tree.findall('region'):
    dico_anno[elem.tag] = elem.text
for elem in tree.findall('event'):
    dico_anno[elem.tag] = elem.text 
for elem in tree.findall("geogName/geogFeat"):
    dico_anno[elem.tag] = elem.text
for elem in tree.findall("gDayName"):
    dico_anno[elem.tag] = elem.text
for elem in tree.findall("time"):
    dico_anno[elem.tag] = elem.text
for elem in tree.findall("country"):
    dico_anno[elem.tag] = elem.text
for elem in tree.findall("term/persName/surname"):
    dico_anno[elem.tag] = elem.text
for elem in tree.findall("nationality"):
    dico_anno[elem.tag] = elem.text
for elem in tree.findall("unit"):
    dico_anno[elem.tag] = elem.text
for elem in tree.findall("demonym"):
    dico_anno[elem.tag] = elem.text
for elem in tree.findall("settlement"):
    dico_anno[elem.tag] = elem.text
for elem in tree.findall("timePeriod"):
    dico_anno[elem.tag] = elem.text
for elem in tree.findall("date/gCentury"):
    dico_anno[elem.text] = elem.tag
print(dico_anno)
# Out:
# {'orgName': "Royaume d' ", 'measure': 'des saisons', 'date': 'en 1996', 'roleName': 'mère', 'org': 'université', 'geogFeat': 'rivière', 'geogName': 'Bali', 'offset': 'Nord de la', 'placeName': 'Bourgogne', 'forename': 'Michel', 'surname': 'Gondry', 'persName': 'Notre-Dame', 'address-number': 'zéro', 'event': 'Actium'}

# %%
dico_anno = {}

for elem in tree.findall('orgName'):
    if elem.text != None:
        dico_anno[elem.text] = elem.tag
for elem in tree.findall('measure'):
    if elem.text != None:
        dico_anno[elem.text] = elem.tag
for elem in tree.findall('date'):
    if elem.text != None:
        dico_anno[elem.text] = elem.tag
for elem in tree.findall('roleName'):
    if elem.text != None:
        dico_anno[elem.text] = elem.tag
for elem in tree.findall('org'):
    if elem.text != None:
        dico_anno[elem.text] = elem.tag
for elem in tree.findall('geogFeat'):
    if elem.tag != None:
        dico_anno[elem.text] = elem.tag
for elem in tree.findall('geogName'):
    if elem.text != None:
        dico_anno[elem.text] = elem.tag
for elem in tree.findall('offset'):
    if elem.text != None:
        dico_anno[elem.text] = elem.tag
for elem in tree.findall('val'):
    if elem.text != None:
        dico_anno[elem.text] = elem.tag
for elem in tree.findall('placeName'):
    if elem.text != None:
        dico_anno[elem.text] = elem.tag
for elem in tree.findall('persName/forename'):
    if elem.text != None:
        dico_anno[elem.text] = elem.tag
for elem in tree.findall('persName/surname'):
    if elem.text != None:
        dico_anno[elem.text] = elem.tag
for elem in tree.findall('persName'):
    if elem.tag != None:
        dico_anno[elem.text] = elem.tag
for elem in tree.findall('extent/measure'):
    if elem.text != None:
        dico_anno[elem.text] = elem.tag
for elem in tree.findall('adress/adrLine/address-number'):
    if elem.text != None:
        dico_anno[elem.text] = elem.tag
for elem in tree.findall('ref'):
    if elem.tag != None:
        dico_anno[elem.text] = elem.tag
for elem in tree.findall('product'):
    if elem.text != None:
        dico_anno[elem.text] = elem.tag
for elem in tree.findall('region'):
    if elem.text != None:
        dico_anno[elem.text] = elem.tag
for elem in tree.findall('event'):
    if elem.text != None:
        dico_anno[elem.text] = elem.tag 
for elem in tree.findall("geogName/geogFeat"):
    if elem.text != None:
        dico_anno[elem.text] = elem.tag
for elem in tree.findall("gDayName"):
    if elem.text != None:
        dico_anno[elem.text] = elem.tag
for elem in tree.findall("time"):
    if elem.text != None:
        dico_anno[elem.text] = elem.tag
for elem in tree.findall("country"):
    if elem.text != None:
        dico_anno[elem.text] = elem.tag
for elem in tree.findall("term/persName/surname"):
    if elem.text != None:
        dico_anno[elem.text] = elem.tag
for elem in tree.findall("nationality"):
    if elem.text != None:
        dico_anno[elem.text] = elem.tag
for elem in tree.findall("unit"):
    if elem.text != None:
        dico_anno[elem.text] = elem.tag
for elem in tree.findall("demonym"):
    if elem.text != None:
        dico_anno[elem.text] = elem.tag
for elem in tree.findall("settlement"):
    if elem.text != None:
        dico_anno[elem.text] = elem.tag
for elem in tree.findall("timePeriod"):
    if elem.text != None:
        dico_anno[elem.text] = elem.tag
for elem in tree.findall("date/gCentury"):
    if elem.text != None:
        dico_anno[elem.text] = elem.tag
print(dico_anno)
# Out:
# {'The Normal': 'orgName', 'Metallica': 'orgName', 'Object Management Group': 'orgName', 'United Service Organizations': 'orgName', "Royaume d' ": 'orgName', 'premiers livres': 'measure', 'premières années': 'measure', 'dix-sept kilomètres': 'measure', 'deux cent quatre-vingt huit kilomètres': 'measure', 'quarante-neuf kilomètres': 'measure', 'vingt-quatre kilomètres': 'measure', 'vingt-sept kilomètres': 'measure', 'quatre-vingt onze kilomètres': 'measure', 'vingt-trois kilomètres': 'measure', 'vingt-six kilomètres': 'measure', 'quatre-vingt dix-neuf kilomètres': 'measure', 'les trente derniers': 'date', 'En 1997': 'date', 'le 6 septembre 1764': 'date', 'en 1989': 'date', 'En 2006': 'date', 'ces 25 dernières': 'date', 'en novembre de la même année': 'date', 'en 2000': 'date', 'en 1922': 'date', 'en 1996': 'date', 'scientifiques': 'roleName', 'auteur': 'roleName', 'écrivains': 'roleName', 'professeurs': 'roleName', 'chef': 'roleName', 'mère': 'roleName', 'consortium ': 'org', 'universi
# ...

# %%
#bon, pour une première mise en dico (puis json, ci-dessous) c'est pas trop mal

# %%
write_json("aijwikinerDico.json", dico_anno)

# %%
for elem in tree.findall('orgName'):
    print(elem.text)
# Out:
# The Normal
# Metallica
# Object Management Group
# United Service Organizations
# Royaume d'

# %%
for elem in tree.findall('measure'):
    print(elem.text)
# Out:
# dix-sept kilomètres
# deux cent quatre-vingt huit kilomètres
# quarante-neuf kilomètres
# vingt-quatre kilomètres
# vingt-sept kilomètres
# quatre-vingt onze kilomètres
# vingt-trois kilomètres
# vingt-six kilomètres
# quatre-vingt dix-neuf kilomètres
# saisons 1979

# %%
for elem in tree.findall('date'):
    print(elem.text)
# Out:
# En 1997
# en 1989
# En 2006
# ces 25 dernières
# en novembre de la même année
# 1980 et 1980

# %%
for elem in tree.findall('roleName'):
    print(elem.text)
# Out:
# auteur
# écrivains
# professeurs

# %%
for elem in tree.findall('org'):
    print(elem.text)
# Out:
# consortium
# université

# %%
for elem in tree.findall('geogFeat'):
    print(elem.text)
# Out:
# île
# Mont
# plaine

# %%
for elem in tree.findall('geogName'):
    print(elem.text)
# Out:
# None
# Bali

# %%
for elem in tree.findall('offset'):
    print(elem.text)
# Out:
# ouest de
# ouest de
# sud de
# nord du
# ouest de
# Nord de la
# Nord de la

# %%
for elem in tree.findall('val'):
    print(elem.text)
# Out:
# des

# %%
for elem in tree.findall('placeName'):
    print(elem.text)
# Out:
# Angleterre
# New York
# Musée du
# Guangdong
# Canton
# Paris
# Saint-Lô
# Cherbourg-Octeville
# Saint-Michel
# Caen
# Chine
# Pékin
# Chine
# Oxford
# Cambridge
# Thionville

# %%
for elem in tree.findall('persName/forename'):
    print(elem.text)
# Out:
# Joy
# John
# Jiang
# Mao
# Michael
# Hong
# Bob

# %%
for elem in tree.findall('persName/surname'):
    print(elem.text)
# Out:
# Division
# Foxx
# Qing
# Zedong
# Faraday
# Elizabeth
# Kong
# Hope
# Division

# %%
for elem in tree.findall('persName'):
    if elem.text != None:
        print(elem.text)
# Out:
# Armstrong
# Notre-Dame

# %%
for elem in tree.findall('extent/measure'):
        print(elem.text)
# Out:
# quelques années

# %%
for elem in tree.findall('adress/adrLine/address-number'):
        print(elem.text)
# Out:
# zéro

# %% [markdown]
# # Fonction pour visualiser les anno

# %%
import xml.etree.ElementTree as ET
def show_annotations(texte):
    elemList = []
    tree=ET.parse(texte)
    for elem in tree.iter():
        if elem.tag not in elemList:
            elemList.append(elem.tag)
    print(elemList)
    print("--------")
    print("OrgName :")
    for elem in tree.findall('orgName'):
        print(elem.text)
    print("--------")
    print("Measure :")
    for elem in tree.findall('measure'):
        print(elem.text)
    print("--------")
    print("Date :")
    for elem in tree.findall('date'):
        if elem.tag != None:
            print(elem.text)
    print("--------")
    print("RoleName :")
    for elem in tree.findall('roleName'):
        print(elem.text)
    print("--------")
    print("Org :")
    for elem in tree.findall('org'):
        print(elem.text)
    print("--------")
    print("GeogFeat :")
    for elem in tree.findall('geogFeat'):
        if elem.text != None:
            print(elem.text)
    print("--------")
    print("GeogName :")
    for elem in tree.findall('geogName'):
        print(elem.text)
    print("--------")
    print("Offset :")
    for elem in tree.findall('offset'):
        print(elem.text)
    print("--------")
    print("Val :")
    for elem in tree.findall('val'):
        print(elem.text)
    print("--------")
    print("PlaceName :")
    for elem in tree.findall('placeName'):
        print(elem.text)
    print("--------")
    print("Forename :")
    for elem in tree.findall('persName/forename'):
        print(elem.text)
    print("--------")
    print("Surname :")
    for elem in tree.findall('persName/surname'):
        print(elem.text)
    print("--------")
    print("PersName :")
    for elem in tree.findall('persName'):
        if elem.text != None:
            print(elem.text)
    print("--------")
    print("Measure for Extent :")
    for elem in tree.findall('extent/measure'):
        print(elem.text)
    print("--------")
    print("Address :")
    for elem in tree.findall('adress/adrLine/address-number'):
        print(elem.text)
    print("--------")
    print("Ref :")
    for elem in tree.findall('ref'):
        if elem.text != None:
            print(elem.text)
    print("--------")
    print("Product :")
    for elem in tree.findall('product'):
        print(elem.text)
    print("--------")
    print("Region :")
    for elem in tree.findall('region'):
        print(elem.text)
    print("--------")
    print("Event :")
    for elem in tree.findall('event'):
        print(elem.text)
    print("--------")
    print("GeogFeat in Geogname :")   
    for elem in tree.findall("geogName/geogFeat"):
        print(elem.text)
    print("--------")
    print("GDayName :")
    for elem in tree.findall("gDayName"):
        print(elem.text)
    print("--------")
    print("Time :")
    for elem in tree.findall("time"):
        print(elem.text)
    print("---------")
    print("Country :")
    for elem in tree.findall("country"):
        print(elem.text)
    print("---------")
    print("term/persName/surname")
    for elem in tree.findall("term/persName/surname"):
        print(elem.text)
    print("---------")
    print("Nationality")
    for elem in tree.findall("nationality"):
        print(elem.text)
    print("-------")
    print("Unit")
    for elem in tree.findall("unit"):
        print(elem.text)
    print("---------")
    print("Demonym")
    for elem in tree.findall("demonym"):
        print(elem.text)
    print("---------")
    print("Settlement")
    for elem in tree.findall("settlement"):
        print(elem.text)
    print("---------")
    print("Time period")
    for elem in tree.findall("timePeriod"):
        print(elem.text)
    print("---------")
    print("gCentury")
    for elem in tree.findall("date/gCentury"):
        print(elem.text)

# %%
# "OrgName", "Measure", "Date", "RoleName", "Org", "GeogFeat",
# "GeogName", "Offset", "Val", "PlaceName", "Forename", "Surname",
# "PersName", "Measure for Extent", "Address", "Ref", "Product",
# "Region", "Event", "GeogFeat in Geogname", "GDayName", "Time"
# "Country", "term/persName/surname", "Nationality"
# "Unit", "Demonym", "Settlement", "timePeriod", "gCentury"

# à traiter :
#<extent>il y a <measure type="duration"><val type="approximatif">
#quelques</val> <unit>semaines</unit></measure></extent>

# %% [markdown]
# # GSD

# %%
show_annotations("GSD_result.txt")
# Out:
# ['s', 'geogFeat', 'placeName', 'persName', 'forename', 'surname', 'ref', 'orgName', 'date', 'roleName', 'org', 'product', 'measure', 'gDayName', 'adress', 'adrLine', 'address-number', 'w', 'region', 'time', 'geogName', 'event']
# --------
# OrgName :
# Nations unies
# département français des
# --------
# Measure :
# 48 heures
# 500 euros
# 5 ans
# --------
# Date :
# de 1930 à 1942
# en 2011
# ces derniers jours
# None
# le 1er janvier 1811
# le 11 avril 1814
# chaque mois
# la journée
# 20 novembre
# --------
# RoleName :
# conceptrice
# patron
# joueurs
# météorologues
# voyageur
# ancien Premier ministre
# évêque
# archevêque
# père
# pilote
# --------
# Org :
# élevage
# entreprises
# --------
# GeogFeat :
# îles
# plateau
# sommet
# --------
# GeogName :
# None
# --------
# Offset :
# --------
# Val :
# --------
# PlaceName :
# Hyères
# France
# Hollywood
# UE
# Maroc
# Afrique
# Antilles
# Saintes
# None
# Bordeaux
# Aquitaine
# département de la
# Collégiale Royale
# Paris
# ...

# %% [markdown]
# # Spoken

# %%
show_annotations('spoken_result.txt')
# Out:
# ['s', 'placeName', 'date', 'gCentury', 'roleName', 'time', 'measure', 'persName', 'forename', 'surname', 'adress', 'adrLine', 'org', 'extent', 'product', 'orgName', 'country', 'geogFeat']
# --------
# OrgName :
# --------
# Measure :
# dix-neuf heures trente
# dix-neuf heures trente
# cent kilomètres
# un livre
# cinq minutes
# --------
# Date :
# None
# le siècle
# tous les jours
# --------
# RoleName :
# général
# médecin
# général
# chef
# boulanger
# --------
# Org :
# boutique
# école
# jardins
# presse
# équipe
# lycée
# --------
# GeogFeat :
# surface
# --------
# GeogName :
# --------
# Offset :
# --------
# Val :
# --------
# PlaceName :
# Saint-Jean
# Maurienne
# Afrique
# Ethiopie
# Somalie
# Arabie
# Aden
# --------
# Forename :
# Paul
# Gabi
# --------
# Surname :
# Vallier
# Heinze
# --------
# PersName :
# Notre-Dame
# Kafka
# Diderot
# --------
# Measure for Extent :
# quatre minutes
# trois minutes
# --------
# Address :
# --------
# Ref :
# --------
# Product :
# ...

# %% [markdown]
# # Sequoia

# %%
show_annotations("Sequoia_result.txt")
# Out:
# ['s', 'persName', 'roleName', 'forename', 'surname', 'placeName', 'date', 'org', 'orgName', 'region', 'measure', 'w', 'ref', 'term', 'nationality', 'geogFeat', 'extent', 'val', 'unit']
# --------
# OrgName :
# Budget
# Conseil
# --------
# Measure :
# un livre
# 2 semaines
# 18 ans
# --------
# Date :
# à partir de 1950
# Le 17 mai 2004
# en 1962
# en 1933
# en 1994
# le jour
# dès septembre 2004
# 20 janvier 1994
# Aujourd'hui
# pour cette nouvelle année
# 28 mai 2004
# le 2 octobre 2006
# dès le mois d' avril 1915
# --------
# RoleName :
# délégués
# ancien ministre socialiste
# procureur
# juges
# auteur
# auteur
# --------
# Org :
# Banque
# entreprise
# Parlement
# --------
# GeogFeat :
# forêt
# --------
# GeogName :
# --------
# Offset :
# --------
# Val :
# --------
# PlaceName :
# Meuse
# France
# Afrique
# Taïwan
# Chine
# Créteil
# ville de
# USA
# Taïwan
# UE
# Europe
# --------
# Forename :
# Christian
# Patrice
# Armand
# Jean-Claude
# Francis
# François
# René
# ...

# %% [markdown]
# # APIL

# %%
#on le fait en dernier

# %%
#<measure type="price"><val>2</val> <unit>€</unit>/<unit>mètre</unit></measure>
#<measure type="length"><unit>km</unit></measure>
#<measure type="length"><unit>km</unit></measure>
#<measure type="length"><unit>km</unit></measure>
#<measure type="price"><unit>€</unit>/<unit>mètre</unit></measure>
#<measure type="price"><unit>€</unit>/<unit>mètre</unit></measure>
#<measure type="price"><val>2</val> <unit>€</unit> le <unit>ml</unit></measure>

# %%
#<date when="-juin-"><extent>Du <val>23</val> au <val>27</val></extent>"><extent>Du <val>23</val> au <val>27</val></extent> juin</date>
#<date when="-juin-"><extent>Du <val>24</val> au <val>26</val></extent>"><extent>Du <val>24</val> au <val>26</val></extent> juin</date>
#<date when="-juillet-"><extent>Du <val>4</val> au <val>29</val></extent>"><extent>Du <val>4</val> au <val>29</val></extent> juillet</date> 
#<date when="-juillet-"><extent>Du <val>8</val> au <val>10</val></extent>"><extent>Du <val>8</val> au <val>10</val></extent> juillet</date>
#<date when="-juillet-"><extent>Du <val>11</val> au <val>15</val></extent>"><extent>Du <val>11</val> au <val>15</val></extent> juillet</date>
#<date when="-juillet-"><extent>Du <val>18</val> au <val>22</val></extent>"><extent>Du <val>18</val> au <val>22</val></extent> juillet</date>
#<date when="-juillet-"><extent>Du <val>22</val> au <val>24</val></extent>"><extent>Du <val>22</val> au <val>24</val></extent> juillet</date>
#<date when="-juillet-"><extent>Du <val>23</val> au <val>27</val></extent>"><extent>Du <val>23</val> au <val>27</val></extent> juillet</date>
#<date when="-août-"><extent>Du <val>2</val> au <val>6</val></extent>"><extent>Du <val>2</val> au <val>6</val></extent> août</date>
#<date when="-août-"><extent>Du <val>5</val> au <val>7</val></extent>"><extent>Du <val>5</val> au <val>7</val></extent> août</date>
#<date when="-août-"><extent>Du <val>8</val> au <val>15</val></extent>"><extent>Du <val>8</val> au <val>15</val></extent> août</date>
#<date when="-août-"><extent>Du <val>13</val> au <val>15</val></extent>"><extent>Du <val>13</val> au <val>15</val></extent> août</date
#<date when="-septembre-"><extent>Du <val>9</val> au <val>11</val></extent>"><extent>Du <val>9</val> au <val>11</val></extent> septembre</date>
#<date when="-septembre-"><extent>Du <val>12</val> au <val>16</val></extent>"><extent>Du <val>12</val> au <val>16</val></extent> septembre</date>
#<date when="-septembre-"><extent>Du <val>16</val> au <val>18</val></extent>"><extent>Du <val>16</val> au <val>18</val></extent> septembre</date>
#

# %%
show_annotations("APIL_result.txt")
# Out:
# ['s', 'persName', 'forename', 'date', 'roleName', 'surname', 'orgName', 'adress', 'adrLine', 'address-number', 'geogName', 'w', 'time', 'org', 'extent', 'val', 'measure', 'placeName', 'product', 'event', 'unit', 'geogFeat', 'demonym', 'ref', 'settlement', 'region', 'gDayName', 'timePeriod', 'nationality', 'offset']
# --------
# OrgName :
# Pays
# Pays
# STOUMONT
# Belgique
# CIEBA
# Bruyères
# CIEBA
# Association LES OMBELLES
# Pays
# PAYS
# Pays
# Stage Co
# COURSAN-EN-OTHE - Retraite
# VAUCHASSIS - Retraite
# BOUILLY - Retraite
# Pays
# PAYS
# Pays
# AVCL Association Vanne Culture Loisirs
# Pays
# Pays
# Cyclo Club Othéen
# Pays
# Ferme
# Ferme
# CIEBA
# CIEBA
# Ferme
# CIEBA
# CIEBA
# CIEBA
# CIEBA
# CIEBA
# CIEBA
# CIEBA
# CIEBA
# CIEBA
# CIEBA
# CIEBA
# CIEBA
# CIEBA
# CIEBA
# Pays
# Pays
# Pays
# Ferme
# AVCL Association Vanne Culture Loisirs
# --------
# Measure :
# 355 €
# 9 h
# 14 h
# 150 €
# 9 h
# 5 €
# 3 €
# 52'
# 5 €
# 3 €
# None
# None
# None
# 10 h
# 10 €
# 9h
# 9 h
# ...

# %% [markdown]
# # Wikinews

# %%
show_annotations("Wikinews_result.txt")
# Out:
# ['s', 'event', 'time', 'unit', 'extent', 'measure', 'date', 'placeName', 'org', 'orgName', 'roleName', 'nationality', 'val', 'adress', 'adrLine', 'w', 'persName', 'surname', 'ref', 'prod.obj', 'name', 'forename', 'org.ent', 'geogFeat', 'offset', 'geogName', 'country']
# --------
# OrgName :
# NASA
# LVMH
# Front National
# --------
# Measure :
# 5S
# 26 ans
# un
# 22 ans
# --------
# Date :
# 9 mars 2018
# le 2 novembre 2017
# le 5 décembre
# En 1952
# La semaine dernière
# 10 mars 2018
# 10 mars 2018
# 10 mars 2018
# avril
# 4 mars
# 14 mars 2018
# du 3 mars
# 3 mars 2018
# 10 mars 2018
# le 20 mars 2018
# Le vendredi 2 mars 2018
# à
# En 1998
# aujourd hui
# 11 mars 2018
# le mois précédent
# 8 mars 2018
# --------
# RoleName :
# juges
# chefs
# CRS
# conducteur
# foreuse
# patineurs
# --------
# Org :
# justice
# laboratoires
# armées
# --------
# GeogFeat :
# Terre
# Terre
# océan
# surface
# --------
# GeogName :
# Pacifique
# --------
# Offset :
# début
# --------
# Val :
# ...

# %%
#il manquait certaines balises fermantes dans le fichier xml donc cela ne fonctionnait pas au début.

# %% [markdown]
# # PG

# %%
show_annotations("pg6470_result.txt")
# Out:
# ['s', 'productName', 'title', 'persName', 'surname', 'roleName', 'amount', 'date', 'measure', 'addName', 'org', 'time', 'adress', 'adrLine', 'orgName', 'extent', 'placeName']
# --------
# OrgName :
# the IRS
# --------
# Measure :
# cinquante francs
# un instant
# --------
# Date :
# auparavant
# au 2 décembre
# tout an
# les journées
# --------
# RoleName :
# gendarmes
# portière
# marchand
# lutteur
# --------
# Org :
# boutique
# jardin
# marines
# --------
# GeogFeat :
# --------
# GeogName :
# --------
# Offset :
# --------
# Val :
# --------
# PlaceName :
# Saint-Eustache
# --------
# Forename :
# --------
# Surname :
# Lisa
# Saget
# Lisa
# Gavard
# Lisa
# Lecoeur
# Lebigre
# Lisa
# --------
# PersName :
# --------
# Measure for Extent :
# quelques francs
# des soirées
# --------
# Address :
# --------
# Ref :
# --------
# Product :
# --------
# Region :
# --------
# Event :
# --------
# GeogFeat in Geogname :
# --------
# GDayName :
# --------
# Time :
# Le soir
# ...

# %%
#idem

# %% [markdown]
# # Fonction pour mettre les annotations en json

# %%
def retourne_dico_anno(texte):
    dic_anno = {}
    tree=ET.parse(texte)
    for elem in tree.findall('orgName'):
        if elem.text != None:
            dic_anno[elem.text] = elem.tag
    for elem in tree.findall('measure'):
        if elem.text != None:
            dic_anno[elem.text] = elem.tag
    for elem in tree.findall('date'):
        if elem.text != None:
            dic_anno[elem.text] = elem.tag
    for elem in tree.findall('roleName'):
        if elem.text != None:
            dic_anno[elem.text] = elem.tag
    for elem in tree.findall('org'):
        if elem.text != None:
            dic_anno[elem.text] = elem.tag
    for elem in tree.findall('geogFeat'):
        if elem.tag != None:
            dic_anno[elem.text] = elem.tag
    for elem in tree.findall('geogName'):
        if elem.text != None:
            dic_anno[elem.text] = elem.tag
    for elem in tree.findall('offset'):
        if elem.text != None:
            dic_anno[elem.text] = elem.tag
    for elem in tree.findall('val'):
        if elem.text != None:
            dic_anno[elem.text] = elem.tag
    for elem in tree.findall('placeName'):
        if elem.text != None:
            dic_anno[elem.text] = elem.tag
    for elem in tree.findall('persName/forename'):
        if elem.text != None:
            dic_anno[elem.text] = elem.tag
    for elem in tree.findall('persName/surname'):
        if elem.text != None:
            dic_anno[elem.text] = elem.tag
    for elem in tree.findall('persName'):
        if elem.tag != None:
            dic_anno[elem.text] = elem.tag
    for elem in tree.findall('extent/measure'):
        if elem.text != None:
            dic_anno[elem.text] = elem.tag
    for elem in tree.findall('adress/adrLine/address-number'):
        if elem.text != None:
            dic_anno[elem.text] = elem.tag
    for elem in tree.findall('ref'):
        if elem.tag != None:
            dic_anno[elem.text] = elem.tag
    for elem in tree.findall('product'):
        if elem.text != None:
            dic_anno[elem.text] = elem.tag
    for elem in tree.findall('region'):
        if elem.text != None:
            dic_anno[elem.text] = elem.tag
    for elem in tree.findall('event'):
        if elem.text != None:
            dic_anno[elem.text] = elem.tag
    for elem in tree.findall("geogName/geogFeat"):
        if elem.text != None:
            dic_anno[elem.text] = elem.tag
    for elem in tree.findall("gDayName"):
        if elem.text != None:
            dic_anno[elem.text] = elem.tag
    for elem in tree.findall("time"):
        if elem.text != None:
            dic_anno[elem.text] = elem.tag
    for elem in tree.findall("country"):
        if elem.text != None:
            dic_anno[elem.text] = elem.tag
    for elem in tree.findall("term/persName/surname"):
        if elem.text != None:
            dic_anno[elem.text] = elem.tag
    for elem in tree.findall("nationality"):
        if elem.text != None:
            dic_anno[elem.text] = elem.tag
    for elem in tree.findall("unit"):
        if elem.text != None:
            dic_anno[elem.text] = elem.tag
    for elem in tree.findall("demonym"):
        if elem.text != None:
            dic_anno[elem.text] = elem.tag
    for elem in tree.findall("settlement"):
        if elem.text != None:
            dic_anno[elem.text] = elem.tag
    for elem in tree.findall("timePeriod"):
        if elem.text != None:
            dic_anno[elem.text] = elem.tag
    for elem in tree.findall("date/gCentury"):
        if elem.text != None:
            dic_anno[elem.text] = elem.tag
    #print(dic_anno)
    write_json("%s.json"%texte, dic_anno)

# %%
retourne_dico_anno("GSD_result.txt")

# %%
retourne_dico_anno("Sequoia_result.txt")

# %%
retourne_dico_anno("pg6470_result.txt")

# %%
retourne_dico_anno("spoken_result.txt")

# %%
retourne_dico_anno("Wikinews_result.txt")

# %%
retourne_dico_anno("APIL_result.txt")

# %%
retourne_dico_anno("aijwikiner_result.txt")

# %% [markdown]
# # Fonction pour mettre les anno principales en json

# %%
def retourne_dico_anno2(texte):
    dic_anno = {}
    tree=ET.parse(texte)
    for elem in tree.findall('orgName'):
        if elem.text != None:
            dic_anno[elem.text] = elem.tag
    for elem in tree.findall('measure'):
        if elem.text != None:
            dic_anno[elem.text] = elem.tag
    for elem in tree.findall('date'):
        if elem.text != None:
            dic_anno[elem.text] = elem.tag
    for elem in tree.findall('roleName'):
        if elem.text != None:
            dic_anno[elem.text] = elem.tag
    for elem in tree.findall('org'):
        if elem.text != None:
            dic_anno[elem.text] = elem.tag
    for elem in tree.findall('geogFeat'):
        if elem.tag != None:
            dic_anno[elem.text] = elem.tag
    for elem in tree.findall('geogName'):
        if elem.text != None:
            dic_anno[elem.text] = elem.tag
    for elem in tree.findall('offset'):
        if elem.text != None:
            dic_anno[elem.text] = elem.tag
    for elem in tree.findall('val'):
        if elem.text != None:
            dic_anno[elem.text] = elem.tag
    for elem in tree.findall('placeName'):
        if elem.text != None:
            dic_anno[elem.text] = elem.tag
    for elem in tree.findall('persName'):
        if elem.tag != None:
            dic_anno[elem.text] = elem.tag
    for elem in tree.findall('adress/adrLine/address-number'):
        if elem.text != None:
            dic_anno[elem.text] = elem.tag
    for elem in tree.findall('ref'):
        if elem.tag != None:
            dic_anno[elem.text] = elem.tag
    for elem in tree.findall('product'):
        if elem.text != None:
            dic_anno[elem.text] = elem.tag
    for elem in tree.findall('region'):
        if elem.text != None:
            dic_anno[elem.text] = elem.tag
    for elem in tree.findall('event'):
        if elem.text != None:
            dic_anno[elem.text] = elem.tag
    for elem in tree.findall("gDayName"):
        if elem.text != None:
            dic_anno[elem.text] = elem.tag
    for elem in tree.findall("time"):
        if elem.text != None:
            dic_anno[elem.text] = elem.tag
    for elem in tree.findall("country"):
        if elem.text != None:
            dic_anno[elem.text] = elem.tag
    for elem in tree.findall("unit"):
        if elem.text != None:
            dic_anno[elem.text] = elem.tag
    for elem in tree.findall("settlement"):
        if elem.text != None:
            dic_anno[elem.text] = elem.tag
    for elem in tree.findall("timePeriod"):
        if elem.text != None:
            dic_anno[elem.text] = elem.tag
    #print(dic_anno)
    write_json("%s_2.json"%texte, dic_anno)

# %%
retourne_dico_anno2("GSD_result.txt")

retourne_dico_anno2("Sequoia_result.txt")

retourne_dico_anno2("pg6470_result.txt")

retourne_dico_anno2("spoken_result.txt")

retourne_dico_anno2("Wikinews_result.txt")

retourne_dico_anno2("APIL_result.txt")

retourne_dico_anno2("aijwikiner_result.txt")
