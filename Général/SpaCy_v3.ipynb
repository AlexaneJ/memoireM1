# %% [markdown]
# # Initialisation

# %%
import spacy

# %%
from spacy.lang.fr import French

# %%
nlp = French()

# %%
import glob, re

# %%
print(glob.glob('*'))
# Out:
# ['Tableur textes _ recueil de données.ods', 'traitementAnnotationsCasEN.ipynb', 'annotations_spacy_v2', 'annotations_spacy_v3', 'SpaCy_v3.ipynb', 'annotations_spacy_v1', 'quaero-guide-annotation-2011.pdf', 'CasEN en Unitex', 'Prise EN Main Unitex', 'annotations_casEN_scripts_v1', 'Textes', 'SpaCy_v1.ipynb', 'ATTENTIONavantUTILISATION_traitementAnnotationsSpaCy.ipynb', 'Introduction à Spacy.ipynb', 'SpaCy_v2.ipynb']

# %%
nlp2 = spacy.load("fr_core_news_lg")

# %%
def ecrire_fichier(chemin, liste):
    w = open(chemin, "w", encoding="utf-8")
    for i in liste:
        w.write("%s \t %s \t %s \t %s\n"%i)
    w.close()

# %%
def trouve_entite(doc, nom_fichier):
    liste = []
    for ent in doc.ents :
        contenu = (ent.text, ent.start_char, ent.end_char, ent.label_)
        liste.append(contenu)
    ecrire_fichier("annotations_spacy_v3/%s_anno_spacy.txt" %nom_fichier, liste)

# %% [markdown]
# # Essai sur CorpusAPIL.txt

# %%
nom_fichier1 = "annotations_spacy_v3bis/%s"
my_file = open(nom_fichier1%"CorpusAPIL_test.sample.txt", "r")
text = my_file.read()

# %%
# on process le texte
doc = nlp2(text)

for token in doc:
    # Get the token text, part-of-speech tag and dependency label
    token_text = token.text
    token_pos = token.pos_
    token_dep = token.dep_
    # This is for formatting only
    print(f"{token_text:<12}{token_pos:<10}{token_dep:<10}")
# Out:
# ERVY-LE-CHATELPROPN     ROOT
# –           PUNCT     punct
# 2ème        ADJ       amod
# jour        NOUN      nmod
# du          DET       case
# Marché      NOUN      nmod
# du          DET       case
# Livre       NOUN      nmod
# à           ADP       case
# la          DET       det
# salle       NOUN      nmod
# des         ADP       case
# fêtes       NOUN      nmod
# de          ADP       case
# 10          NUM       nummod
# h           NOUN      nmod
# à           ADP       case
# 18          NUM       nummod
# h.          NOUN      nmod
# Rencontres  PROPN     ROOT
# avec        ADP       case
# les         DET       det
# auteurs     NOUN      nmod
# ,           PUNCT     punct
# lectures    NOUN      nmod
# entre       ADP       case
# 12          NUM       nummod
# h           NOUN      nmod
# et          CCONJ     cc
# 14          NUM       nummod
# h.          NOUN      nmod
# Organisée   VERB      acl
# par         ADP       case
# «           PUNCT     punct
# ...

# %%
for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
# Out:
# ERVY-LE-CHATEL 0 14 MISC
# Marché du Livre 30 45 MISC
# Rencontres 83 93 LOC
# Ervy-le-Châtel 157 171 LOC
# Reconnaître 5 sauvageonnes comestibles 245 283 MISC
# Les Ombelles 335 347 LOC
# Sortie au départ d’AIX-EN-OTHE 414 444 MISC
# Sortie au Musée Colette 447 470 MISC
# Château de Guédelon 474 493 LOC
# Club des Anciens 511 527 ORG
# Aix 541 544 LOC
# BOUILLY 582 589 ORG
# Marché de Noël 592 606 MISC
# Comité des fêtes 642 658 ORG
# ERVY-LE-CHATEL 660 674 MISC
# Récital de Piano 4 mains 677 701 MISC
# Matthieu Normand 707 723 PER
# Nicolas Collinet 727 743 PER
# Halle Circulaire 749 765 LOC
# Villa de l'Extra 790 806 LOC
# http://villa-de-l-extra.skyrock.com/ 843 879 MISC
# BERULLE 893 900 LOC
# Randonnée 903 912 LOC
# Bérulle 1007 1014 PER
# BOUILLY 1083 1090 ORG
# Téléthon 1093 1101 ORG
# CHAOURCE 1142 1150 LOC
# Concert d’orgue 1153 1168 MISC
# Paul Breisch 1184 1196 PER
# cathédrale de Luxembourg 1203 1227 LOC
# Cabaret itinérant 1268 1285 MISC
# ...

# %%
trouve_entite(doc, "APIL_result")

# %% [markdown]
# # aijwikiner

# %%
nom_fichier1 = "annotations_spacy_v3/%s"
my_file = open(nom_fichier1%"aijwikiner.sample.txt", "r")
text = my_file.read()

# on process le texte
doc = nlp2(text)

trouve_entite(doc, "aijkwikiner_result.txt")

# %% [markdown]
# # GSD

# %%
nom_fichier1 = "annotations_spacy_v3/%s"
my_file = open(nom_fichier1%"fr_gsd-ud-train.conllu.sample.txt", "r")
text = my_file.read()

# on process le texte
doc = nlp2(text)

trouve_entite(doc, "GSD_result.txt")

# %% [markdown]
# # PG

# %%
nom_fichier1 = "annotations_spacy_v3/%s"
my_file = open(nom_fichier1%"pg6470.sample.txt", "r")
text = my_file.read()

# on process le texte
doc = nlp2(text)

trouve_entite(doc, "pg6470_result.txt")

# %% [markdown]
# # Sequoia

# %%
nom_fichier1 = "annotations_spacy_v3/%s"
my_file = open(nom_fichier1%"fr_sequoia-ud-train.conllu.sample.txt", "r")
text = my_file.read()

# on process le texte
doc = nlp2(text)

trouve_entite(doc, "Sequoia_result.txt")

# %% [markdown]
# # Spoken

# %%
nom_fichier1 = "annotations_spacy_v3/%s"
my_file = open(nom_fichier1%"fr_spoken-ud-train.conllu.sample.txt", "r")
text = my_file.read()

# on process le texte
doc = nlp2(text)

trouve_entite(doc, "spoken_result.txt")

# %% [markdown]
# # Wikinews

# %%
nom_fichier1 = "annotations_spacy_v3/%s"
my_file = open(nom_fichier1%"wikinews-2018-03.sample.txt", "r")
text = my_file.read()

# on process le texte
doc = nlp2(text)

trouve_entite(doc, "Wikinews_result.txt")

# %% [markdown]
# # Systématisation

# %%
liste_fichier= ["aijwikiner_result.txt", "APIL_result.txt", "GSD_result.txt", "pg6470_result.txt", "Sequoia_result.txt", "spoken_result.txt", "Wikinews_result.txt"]

# %%
for i in liste_fichier:
    path = "annotations_spacy_v3/%s_result.txt"%i
    mon_fichier2 = open(path, "r")
    text2 = mon_fichier2.read()
    doc2 = nlp2(text2)
    trouve_entite(doc2, i)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-51-a92e39fb2fe2> in <module>
#       1 for i in liste_fichier:
#       2     path = "annotations_spacy_v1/%s_result.txt"%i
# ----> 3     mon_fichier2 = open(path, "r")
#       4     text2 = mon_fichier2.read()
#       5     doc2 = nlp2(text2)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'annotations_spacy_v1/aijwikiner_result.txt_result.txt'
